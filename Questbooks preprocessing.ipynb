# %%
from copy import copy
import re
from string import punctuation
import charset_normalizer
import os
from tqdm import tqdm
import json
import networkx as nx
from networkx.readwrite import json_graph
import pymorphy2
import pandas as pd

# %% [markdown]
# # ENCODING

# %% [markdown]
# The texts have been extracted with different tools and saved in different encodints

# %%
TXT_DIRECTORY = 'D:\Диплом_текстовые_квесты\Data\TXT\part1'

# %%
for file in tqdm(os.listdir(TXT_DIRECTORY)):
    file_path = os.path.join(TXT_DIRECTORY, file)
    with open(file_path, 'rb') as f:
        file_content = f.read()
        detected_encoding = charset_normalizer.detect(file_content)['encoding']
    if detected_encoding != 'utf_8':
        if not detected_encoding:
            detected_encoding='ansi'
        with open(file_path, encoding=detected_encoding) as f:
            text = f.read()
        with open(file_path, 'w', encoding='utf-8') as f:
            f.write(text)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 37/37 [00:34<00:00,  1.06it/s]

# %%
Problem files were resaved manually
# Out:
# 'BB1rusKalgor.txt'

# %% [markdown]
# # DISCHARGE

# %% [markdown]
#     Some quests contain discharge('смотрите, это т е к с т  с  р а з р я д к о й'), which leads to incorrect tokenization and should be removed

# %%
def remove_discharge(lines:list, file2log=None):
    clean_lines = []
    for line in lines:
        discharged_fragments = []
        current_discharged_seq = []
        #two spaces are used as a words separator in discharged fragments
        if '  ' not in line:
            clean_line = line
        else:
            clean_line = copy(line)
            pseudotokens = line.split()
            #collect discharged sequences without joining it
            for token in pseudotokens:
                if len(token.strip(punctuation + '«»')) == 1 and token.strip(punctuation + '«»').isalpha():
                    current_discharged_seq.append(token)
                else:
                    if len(current_discharged_seq) > 3:
                        discharged_fragments.append(current_discharged_seq)
                    current_discharged_seq = []
            if len(current_discharged_seq) > 3:
                discharged_fragments.append(current_discharged_seq)
            if discharged_fragments:
                for discharged_fragment_tokens in discharged_fragments:
                    try:
                        fragment_regexp = '\s+'.join(discharged_fragment_tokens)
                    #get the fragment with the same token separators as in the source text
                        fragment_match = re.search(fragment_regexp, clean_line)
                        if fragment_match:
                            fragment = fragment_match.group()
                        #replace the fragment with the same text without extra separators
                            discharged_tokens = re.split('\s{2,}', fragment)
                            clean_tokens = [''.join(token.split()) for token in discharged_tokens if token]
                            clean_fragment = ' '.join(clean_tokens)
                            clean_line = re.sub(fragment, clean_fragment, clean_line)
                    except:
                        print(file2log)
                        print(line)
        clean_lines.append(clean_line) 
        
    return clean_lines

# %%
test_lines = ['ты знаешь с  н а с т у п л е н ь е м   т е м н о т ы',
             'п ы т а ю с ь  я отсчитывать н а  г л а з,',
             'о т с ч и т ы в а я  горе от версты,',
             'пространство,  р а з д е л я ю щ е е  нас',
             'И числа как-то сходятся в слова,',
              'Откуда  приближаются ко мне']

# %%
remove_discharge(test_lines)
# Out:
# ['ты знаешь с наступленьем темноты',
#  'пытаюсь я отсчитывать на глаз,',
#  'отсчитывая  горе от версты,',
#  'пространство,  разделяющее  нас',
#  'И числа как-то сходятся в слова,',
#  'Откуда  приближаются ко мне']

# %%
for file in tqdm(os.listdir(TXT_DIRECTORY)):
    file_path = os.path.join(TXT_DIRECTORY, file)
    with open(file_path, encoding='utf-8') as f:
        lines = f.readlines()
    clean_lines = remove_discharge(lines, file)
    with open(file_path, 'w', encoding='utf-8') as f:
        f.write(''.join(clean_lines))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 37/37 [00:00<00:00, 45.35it/s]

# %% [markdown]
# # Check punctuation problems

# %% [markdown]
# In some files punctuation is misplaced at the end of the string.

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def punctuation_tends_to_move_to_the_line_end(file_path, num_punctuation_threshold=2, bad_text_threshold=0.3, encoding='utf-8'):
    with open(file_path, encoding=encoding) as f:
        lines = f.readlines()
    num_bad_lines = 0
    num_meaningfull_lines = len([line for line in lines if len(line) > num_punctuation_threshold])
    for line in lines:
        symbols = re.findall('[\S]', line)
        if len(symbols)> num_punctuation_threshold and all([symbol in punctuation+'«»' for symbol in symbols[-num_punctuation_threshold:]]):
            num_bad_lines += 1
    return num_bad_lines >= bad_text_threshold*num_meaningfull_lines and num_meaningfull_lines

# %%
for file in os.listdir(TXT_DIRECTORY):
    if punctuation_tends_to_move_to_the_line_end(os.path.join(TXT_DIRECTORY, file)):
        print(file)
# Out:
# Выбор сотника.txt
# За семью печатями _v1.1.txt
# Заложники пиратского адмирала.txt
# Замок потерянных душ - ч3.txt
# Кристал Каспли.txt
# Лес и трава.txt
# Ловушка - часть 1 (v1.01, A5).txt
# Наперегонки с торнадо.txt

# %% [markdown]
# These files will be reextracted using another tool

# %% [markdown]
# # Unification of the numeration position

# %% [markdown]
# Most of the files contains text fragments with the ids placed at lines like headings. There are several heading parts which are not parts of ids, let's unificate it to make it possible to simplify splitting the text into fragments

# %%
def strip_id_lines_in_file(file_path, fragments_to_remove=['-', '\.', '№', '\*', '§', 'Глава', 'глава', 'п', 'ПАРАГРАФ'], encoding='utf-8'):
    with open(file_path, encoding=encoding) as f:
        lines = f.readlines()
    new_lines = []
    for line in lines:
        try:
            line_without_fragments_to_remove = copy(line)
            for fragment in fragments_to_remove:
                line_without_fragments_to_remove = re.sub(fragment, '', line_without_fragments_to_remove)
            new_lines.append(str(int(line_without_fragments_to_remove))+'\n')
        except ValueError:
            new_lines.append(line)
    with open(file_path, 'w', encoding=encoding) as f:
        f.write(''.join(new_lines))

# %%
for file in tqdm(os.listdir(TXT_DIRECTORY)):
    strip_id_lines_in_file(os.path.join(TXT_DIRECTORY, file))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 37/37 [00:02<00:00, 12.61it/s]

# %% [markdown]
# Let's detect files, there the id-like line is not the first non-empty one, and assert, that

# %%
def starts_with_id(file_lines:list):
    for line in file_lines:
        if line.strip():
            try:
                number = int(line)
                return True
            except ValueError:
                return False

# %%
def ids_are_ordered(file_lines:list):
    are_ordered = True
    previous_id = -1
    for line in file_lines:
        try:
            number = int(line)
            if number > previous_id:
                previous_id = number
            else:
                are_ordered = False
                print(number, previous_id)
                previous_id = number
        except ValueError:
            continue
    return are_ordered

# %%
not_ordered_files = []
for file in os.listdir(TXT_DIRECTORY):
    file_path = os.path.join(TXT_DIRECTORY, file)
    with open(os.path.join(TXT_DIRECTORY, file_path), encoding='utf-8') as f:
        lines = f.readlines()
    if not ids_are_ordered(lines):
        print(file)
        not_ordered_files.append(file)
# Out:
# 27 62
# 42 68
# 43 78
# Растревоженный Манхеттен.txt
# 37 87
# 142 158
# Резонанс (светлая версия).txt
# 6 55
# 38 3737
# 45 4444
# 50 4949
# 62 6161
# 68 6767
# 73 7272
# 86 8585
# 88 8787
# 92 9191
# 94 497
# 99 9898
# 110 108108
# 115 113113
# 117 116116
# 145 143143
# 151 150150
# 165 163163
# 175 173173
# 187 185185
# 194 192192
# 200 199199
# 206 205205
# 242 240240
# 246 243243
# 257 256256
# 272 271271
# 278 276276
# 282 280280
# 302 299299
# 306 305305
# 314 313313
# 320 318318
# 324 323323
# 341 339339
# 355 354354
# 359 357357
# 372 370370
# 397 395395
# 400 399399
# 412 411411
# 416 414414
# 421 419419
# 430 428428
# 444 443443
# 451 449449
# 465 463463
# 468 467467
# 471 469469
# 479 478478
# 489 487487
# 499 497497
# 523 522522
# 527 525525
# 537 534534
# 541 538538
# 543 542542
# 548 547547
# 560 559559
# 573 572572
# 575 574574
# 583 580580
# 591 590590
# 614 611611
# 625 624624
# 640 637637
# 642 641641
# 645 643643
# Робур2 - Город Вин 2.txt
# 39 46
# 44 94
# 49 65
# 58 66
# 70 72
# 40 99
# Рубка_драка.txt
# 1 2017
# Рыцари Погибели (1.0).txt
# 6 224
# 232 301
# 1 566
# 1 1
# 1 3
# 1 2
# 1 5
# 1 1
# 2 2
# 1 3
# 1 2
# 1 2
# 1 1
# 1 3
# 1 2
# 1 5
# 1 1
# 2 2
# 1 3
# 1 2
# Рыцарь живых мертвецов (v1.0).txt
# 8 14
# 12 39
# 16 25
# Саксонские войны.txt
# 339 355
# 24 461
# 383 451
# 26 423
# 373 403
# 360 373
# 37 449
# 341 366
# 394 472
# 38 432
# 439 475
# 344 456
# 39 356
# 47 294
# 332 480
# 379 441
# 50 379
# 76 147
# 331 459
# 396 484
# 347 396
# 92 347
# 95 122
# 405 413
# 392 405
# 377 392
# 364 377
# 97 364
# 359 421
# 98 490
# 371 418
# 348 486
# 99 406
# 353 427
# 408 450
# 388 408
# 248 388
# 109 248
# 438 462
# 362 438
# 375 390
# 116 375
# 434 474
# 411 434
# 336 411
# 124 460
# 399 469
# 354 409
# 172 354
# 391 495
# 422 476
# 176 422
# 177 318
# 179 483
# 400 497
# 349 468
# 180 416
# 372 478
# 352 372
# 382 455
# 186 382
# 369 429
# 335 481
# 190 412
# 334 440
# 345 488
# 286 345
# 192 286
# 106 196
# 199 315
# 464 482
# 350 464
# 224 350
# 420 494
# 230 457
# 183 234
# 415 437
# 361 415
# 333 485
# 245 333
# 351 367
# 443 491
# 264 471
# 417 489
# 374 417
# 273 465
# 454 467
# 431 454
# 376 431
# 343 376
# 275 343
# 371 418
# 348 486
# 277 406
# 284 300
# 439 475
# 344 456
# 288 356
# 464 482
# 350 464
# 294 350
# 378 453
# 447 477
# 428 447
# 301 428
# 414 493
# 385 473
# 304 385
# 452 470
# 433 452
# 424 487
# 311 424
# 331 459
# 396 484
# 347 396
# 317 347
# 346 466
# 387 448
# 330 387
# 168 347
# 256 349
# 268 382
# 419 464
# 350 482
# 309 407
# 271 423
# 251 439
# 20 454
# 41 467
# 185 478
# 277 484
# 497 498
# 4 498
# 4 4
# 4 4
# 4 4
# 4 4
# 4 4
# Семь змей.txt
# 16 158
# Сказание_о_Загоре.txt
# 10 115
# 22 36
# 2 38
# 53 106
# 22 67
# 63 75
# 84 88
# 86 96
# 88 125
# 7 127
# Скипетр Нижнего мира.txt
# 23 111
# 100 129
# 112 239
# 194 262
# Склеп вампира.txt
# 35 50
# 36 50
# 33 76
# Смертоносная тень - Часть 1 _.txt
# 10 366
# 11 124
# 31 145
# 53 334
# 59 189
# 60 185
# 64 126
# 40 89
# 92 156
# 159 258
# 163 343
# 165 373
# 185 240
# 12 194
# 212 248
# 57 265
# 223 270
# 171 283
# 118 302
# 121 348
# 300 359
# 36 384
# Спектральные сталкеры.txt
# 6 67
# 2 11
# 22 26
# 31 726
# 38 71
# 27 40
# 49 102
# 58 61
# 43 68
# 75 190
# 84 87
# 85 792
# 86 92
# 1 92
# 1 100
# 110 122
# 133 171
# 141 800
# 148 163
# 151 802
# 4 159
# 132 161
# 181 184
# 184 187
# 1 188
# 192 204
# 245 255
# 260 264
# 245 264
# 214 265
# 287 290
# 60 297
# 1 298
# 50 301
# 156 308
# 35 314
# 1 323
# 321 325
# 315 326
# 59 333
# 333 334
# 3 340
# 347 350
# 352 358
# 1 364
# 365 386
# 1 367
# 1 372
# 374 379
# 376 385
# 66 382
# 394 402
# 402 406
# 414 421
# 418 428
# 407 418
# 10 428
# 429 439
# 113 449
# 117 450
# 462 466
# 477 481
# 2 488
# 491 544
# 84 539
# 84 545
# 553 557
# 4 584
# 598 602
# 614 694
# 617 621
# 1 618
# 3 624
# 632 637
# 624 639
# 180 652
# 180 653
# 660 667
# 665 673
# 50 667
# 600 698
# 185 722
# 764 767
# 767 768
# 764 781
# 4 819
# Тачанка - книга-игра.txt
# 1 252
# 1 306
# 5 304
# 314 353
# Три дороги (v1.1).txt
# 12 45
# 35 76
# 32 53
# 78 111
# 102 122
# Ты-удобрение для растений.txt
# 47 148
# 178 251
# 294 421
# 342 436
# 456 632
# 536 610
# 545 775
# 629 1084
# 775 957
# Угроза с Дикого Кладбища.txt
# 15 105
# 25 82
# 26 157
# 46 100
# 87 143
# 99 154
# 107 169
# 78 107
# 84 131
# 143 165
# Усыпальницы Королей.txt
# 58 164
# 89 168
# Филипп Эбли - Остров осьминогов - А5.txt
# 3 105
# 16 144
# 33 231
# 43 279
# 51 196
# 57 183
# 111 202
# 28 193
# 199 257
# 220 232
# 228 456
# 242 275
# 220 262
# 71 282
# 220 300
# 64 324
# 169 339
# 117 342
# 201 362
# 74 402
# Холмы Шамутанти.txt
# 2 34
# 1 9
# 13 34
# 12 34
# 223 391
# 35 367
# 1 50
# 34 58
# 66 236
# 39 72
# 1 78
# 106 376
# 88 114
# 8 119
# 3 154
# 74 172
# 175 188
# 1 177
# 25 180
# 183 340
# 4 183
# 1 194
# 201 236
# 77 208
# 34 223
# 33 232
# 234 298
# 238 371
# 4 245
# 1 247
# 34 264
# 4 266
# 4 295
# 105 296
# 34 301
# 121 309
# 134 313
# 49 315
# 4 317
# 98 322
# 2 326
# 34 342
# 4 343
# 8 363
# 34 367
# 46 370
# 2 383
# 1 391
# 3 395
# Храм ужаса.txt
# 9 11
# 41 99
# 44 116
# 45 75
# 39 64
# 58 82
# 106 122
# Цирк - западня.txt
# 61 7590
# 88 136
# Человекосжималки.txt
# 171 454
# 148 237
# 109 554
# 317 591
# Шерлок Холмс 3 (без фона) v1.1.txt
# 7 20
# 2 26
# 13 14
# 7 36
# 7 17
# 7 42
# 2 26
# 13 14
# 7 48
# 2 17
# 13 14
# 7 63
# 4 17
# 14 17
# 7 74
# 4 17
# 14 17
# Элгар Флетч.txt

# %%
for file in ['Наперегонки с торнадо.txt']:
    file_path = os.path.join(TXT_DIRECTORY, file)
    with open(os.path.join(TXT_DIRECTORY, file_path), encoding='utf-8') as f:
        lines = f.readlines()
    if not ids_are_ordered(lines):
        print(file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-01f676aa7c48> in <module>
#       1 for file in ['Наперегонки с торнадо.txt']:
#       2     file_path = os.path.join(TXT_DIRECTORY, file)
# ----> 3     with open(os.path.join(TXT_DIRECTORY, file_path), encoding='utf-8') as f:
#       4         lines = f.readlines()
#       5     if not ids_are_ordered(lines):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\Диплом_текстовые_квесты\\Data\\TXT\\part2\\Наперегонки с торнадо.txt'

# %%
not_ordered_files
# Out:
# ['BB1rusKalgor.txt',
#  'Cherniy continent.txt',
#  'dq1_tlos_v1.0.txt',
#  'dzhungar_v1.0.txt',
#  'Fabled_Lands_5_The_Court_Of_Hidden_Faces_RUS.txt',
#  'Fabled_Lands_6_Lords_of_the_Rising_Sun_RUS.txt',
#  'Face2face.txt',
#  'Fallout II v1.04.5.txt',
#  'FF05 - Город воров (v1.01).txt',
#  'FF21 - Глаз дракона.txt',
#  'ff44_rus.txt',
#  'FF7 (А5, версия 1.0).txt',
#  'fftd_x1.txt',
#  'fu (v1.1).txt',
#  'GD-demo.txt',
#  'logovo.txt',
#  'serdcelda.txt',
#  'SW4 (A5, v1.0).txt',
#  'SW5 (A5, v1.0).txt',
#  'Vasiliy_Pupkin.txt',
#  'Адское болото.txt',
#  'Алдар Косе приключения безбородого обманщика v4.2.txt',
#  'Башня Ужаса (A4, 1.0).txt',
#  'Боевые ямы Крарта.txt',
#  'Болотная лихорадка (v1.0).txt',
#  'Булава Ужаса.txt',
#  'В поисках рождества.txt',
#  'В стране высоких трав.txt',
#  'Владыка степей (1.2.1b).txt',
#  'Возвращение.txt',
#  'Воин острого клинка.txt',
#  'Вой оборотня.txt',
#  'Воля зоны.txt',
#  'Выбор сотника.txt',
#  'Генезис 1.6.txt',
#  'Города Золота и Славы.txt',
#  'Демоны бездны.txt',
#  'Дом Дьявола.txt',
#  'За семью печатями _v1.1.txt',
#  'Заложники пиратского адмирала.txt',
#  'Идущий на смех.txt',
#  'Каникулы в джунглях.txt',
#  'Капитан Морской ведьмы.txt',
#  'Кинжалы во тьме.txt',
#  'книга игра - История одного отставного Стража.txt',
#  'Книга-игра Та самая игра.txt',
#  'Колдунья и книга заклинаний.txt',
#  'Кольцо джинна.txt',
#  'Кошки-мышки.txt',
#  'Кощеева цепь.txt',
#  'Кровавые кости.txt',
#  'Курортный роман.txt',
#  'Кхар, город ловушек.txt',
#  'Лабиринт Страха.txt',
#  'Легенды_1колонка.txt',
#  'Ловушка - часть 2 (A5).txt',
#  'Лунатик.txt',
#  'Мадам Гильотина (v1.0, A5).txt',
#  'Майкл Фрост - Чернолесье.txt',
#  'Месть Альтея.txt',
#  'Меч самурая.txt',
#  'Морская лихорадка (v1.0, A5).txt',
#  'Морские байки (1.2).txt',
#  'Наемная убийца (v1.0).txt',
#  'Наперегонки с торнадо.txt',
#  'Наставники всегда правы.txt',
#  'Наступление тьмы.txt',
#  'Непредвиденный пассажир.txt',
#  'Ночь в лесу оборотней.txt',
#  'Ночь по ту сторону Смерти (A5, v1.0).txt',
#  'Общество червей (v1.0).txt',
#  'Один против Империи.txt',
#  'Один против пламени.txt',
#  'Одинокий волк 2 - Огонь на воде.txt',
#  'Операция Кладенец.txt',
#  'Оружие возмездия - книга-игра.txt',
#  'Остров крови.txt',
#  'Пещеры Кальте (beta).txt',
#  'Пиратская одиссея.txt',
#  'По воле Рима.txt',
#  'По Кровавому морю (A5, v1.00beta).txt',
#  'По следам героя.txt',
#  'Побег.txt',
#  'Подземелья замка кошмаров.txt',
#  'Портал зла.txt',
#  'Притча о том, как Пич Квачо генерала спас.txt',
#  'Проект1 - 3.0.1.txt',
#  'Проклятый лес (A5, v1.0).txt',
#  'Проклятье мумии.txt',
#  'Пророчество о черной династии.txt',
#  'Прорыв (v1.0).txt',
#  'Пурпурные земли (A5).txt']

# %%
with open(os.path.join(TXT_DIRECTORY, 'dq1_tlos_v1.0.txt'), encoding='utf-8') as f:
    lines = f.readlines()
needs_checking = not ids_are_ordered(lines)
# Out:
# 93 154
# 2 93
# 153 227
# 4 153
# 20 27
# 5 34
# 6 129
# 7 72
# 8 60
# 9 238
# 10 255
# 11 23
# 16 75
# 6 16
# 13 34
# 78 200
# 14 78
# 5 14
# 15 129
# 16 163
# 17 128
# 18 149
# 19 26
# 53 245
# 42 53
# 20 42
# 21 34
# 14 28
# 22 129
# 23 148
# 17 23
# 24 30
# 11 24
# 25 259
# 32 39
# 3 32
# 20 27
# 28 34
# 14 129
# 30 44
# 17 30
# 32 163
# 3 39
# 34 94
# 35 51
# 153 153
# 36 153
# 38 77
# 39 145
# 32 39
# 3 32
# 41 83
# 42 170
# 11 245
# 44 253
# 46 62
# 6 175
# 48 171
# 49 246
# 50 80
# 36 50
# 52 144
# 53 170
# 42 245
# 11 42
# 24 67
# 226 237
# 205 226
# 55 259
# 56 96
# 46 56
# 6 46
# 58 164
# 60 127
# 61 91
# 62 235
# 40 62
# 64 241
# 65 82
# 50 65
# 61 66
# 67 79
# 54 67
# 11 54
# 46 85
# 57 164
# 55 70
# 72 181
# 86 238
# 8 86
# 101 137
# 74 101
# 75 154
# 11 75
# 21 95
# 58 261
# 61 79
# 82 234
# 84 144
# 42 245
# 11 42
# 114 132
# 46 114
# 8 238
# 88 195
# 1 173
# 91 166
# 48 270
# 93 155
# 94 167
# 81 94
# 21 95
# 97 119
# 98 156
# 99 222
# 250 256
# 100 250
# 101 127
# 102 142
# 103 126
# 104 273
# 153 153
# 106 153
# 107 296
# 99 107
# 101 137
# 110 123
# 68 110
# 46 68
# 112 249
# 1 112
# 73 223
# 108 177
# 68 114
# 46 68
# 153 301
# 116 153
# 47 254
# 118 207
# 119 143
# 120 151
# 121 266
# 122 133
# 123 140
# 124 146
# 125 228
# 96 125
# 107 126
# 127 136
# 128 197
# 54 128
# 11 54
# 71 159
# 131 161
# 132 548
# 68 132
# 46 68
# 1 182
# 165 192
# 136 165
# 99 136
# 92 137
# 106 138
# 140 204
# 102 140
# 188 196
# 141 188
# 59 141
# 142 157
# 121 142
# 143 217
# 144 150
# 145 230
# 271 280
# 147 271
# 148 208
# 63 148
# 37 149
# 152 168
# 151 152
# 158 169
# 152 158
# 153 240
# 117 244
# 109 194
# 155 160
# 89 155
# 122 156
# 158 197
# 201 220
# 159 201
# 118 159
# 146 160
# 151 161
# 163 414
# 139 163
# 31 139
# 165 178
# 140 165
# 134 166
# 88 134
# 74 167
# 169 184
# 158 180
# 189 193
# 172 189
# 173 252
# 112 173
# 1 112
# 175 251
# 46 191
# 103 176
# 113 177
# 101 137
# 43 178
# 180 231
# 158 180
# 182 203
# 98 182
# 1 98
# 184 225
# 185 199
# 58 185
# 103 186
# 100 187
# 126 188
# 147 189
# 191 242
# 175 191
# 46 175
# 140 192
# 189 193
# 109 194
# 137 195
# 113 137
# 101 113
# 126 196
# 90 209
# 183 198
# 152 199
# 200 219
# 78 200
# 202 233
# 103 248
# 124 203
# 65 204
# 11 205
# 67 259
# 207 225
# 41 207
# 103 254
# 90 209
# 211 257
# 58 236
# 266 295
# 213 266
# 282 348
# 214 282
# 172 214
# 216 475
# 293 307
# 217 293
# 133 217
# 198 218
# 176 198
# 220 240
# 221 247
# 153 221
# 153 153
# 1 222
# 113 223
# 101 137
# 225 263
# 226 231
# 11 226
# 67 259
# 115 301
# 230 255
# 125 230
# 7 231
# 232 246
# 116 232
# 174 233
# 235 243
# 33 235
# 13 236
# 11 237
# 67 259
# 202 238
# 179 239
# 64 240
# 211 241
# 185 289
# 243 260
# 153 244
# 153 153
# 53 245
# 42 53
# 11 42
# 2 246
# 248 251
# 232 262
# 250 290
# 172 250
# 224 252
# 254 264
# 218 254
# 103 218
# 38 255
# 172 256
# 258 290
# 232 258
# 54 259
# 11 54
# 229 261
# 9 229
# 258 262
# 264 299
# 187 264
# 138 187
# 265 274
# 266 348
# 231 266
# 268 348
# 269 284
# 270 348
# 246 270
# 273 522
# 274 285
# 106 274
# 277 284
# 278 367
# 269 354
# 280 349
# 76 280
# 282 424
# 265 303
# 283 348
# 284 361
# 285 387
# 212 285
# 287 320
# 288 361
# 289 345
# 211 289
# 58 211
# 69 290
# 57 69
# 279 291
# 292 349
# 293 344
# 294 379
# 295 317
# 120 295
# 197 296
# 298 879
# 220 298
# 201 220
# 275 299
# 301 644
# 115 301
# 424 455
# 303 424
# 265 303
# 304 348
# 305 486
# 292 305
# 306 331
# 307 424
# 293 307
# 309 429
# 348 369
# 310 348
# 334 504
# 311 516
# 312 404
# 279 312
# 313 349
# 314 394
# 315 528
# 381 395
# 316 381
# 526 538
# 317 526
# 318 355
# 319 514
# 336 376
# 320 336
# 277 320
# 322 483
# 424 505
# 323 424
# 324 529
# 325 446
# 292 325
# 326 344
# 284 326
# 268 284
# 327 339
# 328 451
# 329 518
# 526 538
# 330 526
# 213 330
# 331 348
# 292 331
# 294 402
# 333 345
# 310 334
# 336 377
# 337 430
# 283 337
# 339 348
# 284 339
# 268 284
# 438 457
# 341 438
# 328 342
# 344 476
# 345 409
# 312 345
# 348 353
# 362 404
# 349 373
# 317 349
# 351 418
# 340 462
# 353 370
# 354 393
# 309 354
# 356 405
# 342 356
# 341 357
# 314 358
# 360 386
# 424 460
# 361 424
# 327 361
# 348 362
# 364 474
# 346 364
# 358 365
# 367 491
# 368 382
# 369 461
# 338 369
# 371 391
# 310 371
# 372 421
# 373 428
# 286 373
# 267 286
# 360 374
# 308 360
# 287 375
# 319 417
# 383 425
# 336 383
# 378 407
# 404 420
# 379 404
# 352 379
# 465 478
# 381 465
# 382 474
# 216 382
# 376 383
# 336 376
# 378 420
# 385 404
# 386 392
# 162 386
# 388 396
# 389 426
# 322 390
# 391 493
# 359 391
# 393 450
# 368 393
# 395 410
# 396 474
# 294 396
# 288 294
# 398 482
# 399 414
# 400 435
# 401 426
# 310 401
# 312 402
# 403 413
# 337 403
# 384 404
# 311 384
# 406 416
# 407 525
# 302 408
# 372 409
# 410 428
# 378 420
# 413 482
# 312 413
# 416 428
# 399 416
# 376 417
# 420 433
# 411 420
# 378 411
# 310 459
# 423 515
# 527 578
# 424 527
# 425 535
# 376 425
# 336 376
# 427 655
# 343 427
# 403 428
# 375 403
# 424 445
# 431 466
# 432 569
# 433 626
# 434 442
# 435 453
# 374 435
# 437 604
# 520 701
# 438 520
# 439 452
# 426 439
# 440 502
# 343 440
# 442 604
# 443 558
# 444 637
# 445 539
# 281 445
# 439 447
# 343 448
# 450 479
# 473 532
# 451 480
# 452 481
# 304 512
# 454 725
# 455 708
# 392 455
# 393 456
# 412 457
# 304 412
# 459 539
# 421 459
# 371 421
# 302 460
# 463 497
# 454 463
# 215 454
# 424 487
# 456 465
# 393 456
# 467 513
# 468 538
# 351 468
# 340 351
# 424 469
# 471 544
# 472 482
# 473 508
# 464 473
# 475 495
# 426 475
# 343 549
# 465 478
# 393 465
# 480 501
# 390 480
# 482 494
# 483 506
# 484 538
# 496 530
# 485 496
# 472 485
# 486 524
# 487 509
# 488 515
# 397 488
# 356 489
# 491 533
# 449 491
# 493 777
# 424 505
# 318 494
# 495 524
# 356 495
# 497 540
# 304 497
# 515 521
# 499 515
# 500 619
# 502 523
# 439 738
# 490 503
# 485 490
# 401 504
# 310 401
# 487 505
# 424 487
# 304 506
# 215 507
# 353 508
# 347 353
# 406 509
# 511 716
# 526 538
# 512 526
# 458 513
# 444 458
# 472 514
# 515 524
# 310 516
# 472 517
# 518 524
# 519 534
# 484 519
# 521 725
# 515 521
# 393 522
# 524 537
# 472 536
# 376 525
# 527 560
# 528 568
# 472 528
# 530 542
# 496 530
# 732 762
# 532 732
# 464 545
# 472 533
# 323 534
# 422 535
# 365 536
# 468 537
# 457 468
# 438 457
# 329 538
# 316 511
# 540 550
# 507 540
# 215 507
# 542 750
# 479 542
# 544 565
# 545 587
# 487 545
# 424 487
# 547 728
# 548 726
# 496 548
# 550 572
# 551 562
# 552 585
# 553 700
# 500 553
# 597 607
# 554 597
# 443 554
# 556 732
# 557 619
# 558 616
# 559 729
# 531 559
# 560 579
# 519 560
# 581 598
# 562 581
# 564 571
# 565 584
# 447 565
# 439 447
# 567 580
# 568 610
# 551 573
# 510 569
# 470 510
# 571 743
# 713 744
# 706 713
# 572 706
# 431 572
# 574 585
# 437 574
# 576 600
# 577 619
# 578 743
# 568 578
# 580 591
# 581 599
# 582 610
# 583 754
# 453 583
# 300 761
# 586 592
# 587 729
# 574 587
# 676 753
# 553 676
# 590 656
# 453 590
# 546 591
# 437 593
# 570 594
# 596 765
# 576 596
# 686 697
# 672 686
# 659 672
# 598 659
# 599 610
# 600 628
# 601 605
# 732 740
# 602 732
# 603 741
# 596 626
# 566 604
# 606 612
# 554 614
# 553 737
# 609 630
# 610 638
# 556 619
# 553 611
# 681 772
# 613 681
# 614 647
# 643 658
# 615 643
# 616 759
# 617 752
# 618 710
# 619 639
# 554 619
# 621 654
# 622 704
# 731 735
# 623 731
# 625 771
# 617 625
# 432 640
# 628 748
# 629 651
# 674 679
# 630 674
# 615 781
# 632 718
# 633 766
# 626 648
# 553 634
# 636 749
# 436 636
# 638 696
# 742 769
# 641 742
# 639 641
# 624 639
# 626 640
# 742 769
# 642 742
# 629 643
# 492 644
# 622 645
# 646 727
# 623 646
# 647 667
# 648 763
# 626 648
# 650 710
# 723 770
# 651 723
# 652 767
# 443 652
# 645 653
# 654 661
# 625 654
# 655 662
# 423 655
# 657 673
# 658 688
# 443 658
# 597 659
# 553 597
# 661 682
# 662 731
# 649 662
# 664 696
# 731 735
# 665 731
# 666 757
# 608 666
# 670 683
# 646 670
# 672 798
# 597 680
# 553 597
# 621 673
# 646 674
# 632 675
# 553 691
# 678 710
# 679 715
# 680 685
# 597 680
# 553 597
# 682 776
# 683 782
# 684 739
# 665 684
# 685 748
# 686 696
# 597 686
# 553 597
# 661 721
# 689 690
# 671 690
# 691 780
# 634 691
# 553 634
# 693 710
# 695 703
# 666 695
# 670 696
# 597 697
# 553 597
# 611 698
# 553 611
# 700 705
# 732 745
# 701 732
# 702 709
# 601 702
# 661 712
# 705 717
# 714 773
# 706 714
# 707 725
# 668 707
# 475 708
# 583 709
# 434 583
# 712 757
# 687 712
# 661 687
# 714 725
# 715 720
# 587 716
# 723 778
# 718 723
# 627 718
# 720 734
# 702 736
# 721 732
# 653 721
# 723 728
# 715 723
# 725 747
# 561 725
# 727 734
# 731 735
# 728 731
# 552 728
# 636 729
# 650 730
# 707 731
# 734 747
# 594 734
# 731 735
# 601 736
# 553 737
# 400 738
# 693 739
# 733 740
# 724 733
# 742 746
# 641 769
# 744 747
# 725 744
# 541 745
# 747 764
# 559 747
# 631 748
# 750 755
# 732 750
# 752 760
# 642 752
# 698 753
# 553 698
# 756 764
# 620 756
# 675 757
# 730 758
# 723 730
# 654 759
# 748 760
# 300 761
# 591 762
# 699 763
# 602 764
# 609 766
# 669 767
# 723 775
# 770 779
# 678 770
# 694 771
# 695 772
# 547 773
# 775 782
# 758 775
# 666 776
# 768 778
# 774 779
# 660 774
# 781 798
# 756 781
# 657 782
# 795 898
# 784 795
# 862 925
# 785 862
# 786 828
# 825 831
# 787 825
# 789 886
# 862 929
# 791 862
# 803 815
# 792 803
# 829 837
# 800 829
# 853 915
# 793 853
# 794 857
# 795 884
# 791 795
# 852 875
# 796 852
# 798 849
# 835 932
# 799 835
# 800 904
# 792 800
# 802 824
# 793 802
# 789 815
# 796 812
# 810 913
# 806 810
# 807 920
# 808 935
# 810 905
# 792 810
# 812 866
# 787 812
# 814 863
# 815 834
# 803 815
# 789 803
# 796 888
# 297 817
# 862 922
# 819 862
# 820 939
# 821 902
# 785 821
# 822 885
# 823 842
# 784 823
# 907 918
# 825 907
# 826 910
# 827 901
# 820 827
# 890 921
# 829 890
# 792 829
# 815 830
# 803 914
# 881 903
# 831 881
# 790 831
# 833 895
# 797 833
# 834 894
# 835 859
# 836 938
# 837 900
# 792 837
# 839 902
# 789 903
# 804 840
# 842 848
# 862 874
# 843 862
# 811 843
# 818 844
# 845 909
# 846 856
# 838 846
# 824 847
# 849 926
# 862 906
# 850 862
# 851 883
# 881 914
# 853 881
# 792 853
# 794 854
# 855 885
# 856 887
# 857 895
# 799 857
# 859 928
# 860 926
# 795 898
# 809 861
# 862 905
# 864 884
# 833 864
# 811 865
# 867 885
# 816 867
# 869 927
# 808 869
# 851 870
# 871 933
# 824 871
# 873 891
# 874 939
# 808 874
# 839 875
# 876 903
# 824 876
# 826 877
# 862 916
# 790 880
# 789 914
# 824 882
# 844 883
# 905 921
# 885 905
# 821 924
# 796 892
# 824 887
# 806 888
# 806 889
# 891 905
# 805 891
# 846 892
# 811 893
# 883 931
# 905 921
# 896 905
# 897 928
# 872 897
# 860 898
# 795 860
# 900 936
# 897 900
# 802 897
# 902 928
# 903 909
# 839 903
# 789 839
# 862 912
# 861 905
# 906 930
# 841 906
# 908 928
# 793 908
# 878 909
# 816 910
# 862 923
# 913 919
# 792 913
# 881 914
# 789 881
# 908 915
# 822 916
# 876 917
# 801 876
# 919 928
# 880 919
# 862 880
# 840 920
# 877 921
# 902 922
# 786 902
# 850 923
# 832 924
# 814 925
# 857 926
# 836 857
# 828 927
# 934 937
# 873 934
# 819 873
# 929 939
# 917 930
# 905 917
# 911 931
# 899 932
# 928 934
# 935 939
# 865 935
# 843 893
# 807 936
# 928 937
# 938 939
# 936 938
# 870 939

# %%
needs_checking
# Out:
# True

# %%
need_beginning_cleaning = []
need_order_checking = []
for file in os.listdir(TXT_DIRECTORY):
    file_path = os.path.join(TXT_DIRECTORY, file)
    with open(file_path, encoding='utf-8') as f:
        lines = f.readlines()
    if not starts_with_id(lines):
        need_beginning_cleaning.append(file)
    if not ids_are_ordered:
        need_order_checking.append(file)

# %%
need_beginning_cleaning
# Out:
# ['Рыцари Погибели (1.0).txt']

# %%
need_order_checking
# Out:
# []

# %% [markdown]
# As all the ids are ordered, let's ignore all the lines before the first id

# %%
def get_id4number(line:str, previous_id=None, check_order=True):
    try:
        number = int(line)
        if type(previous_id) not in [str, int] or number == int(previous_id)+1 or not check_order:
            return line.strip()
        else:
            return None
    except Exception as e:
        return None

# %%
res = get_id4number('1')

# %%
if type(None):
    print('exists')
# Out:
# exists

# %%
def split_quest(file_path, detecting_id_function, needs_order_checking=False, encoding='utf-8'):
    with open(file_path, encoding=encoding) as f:
        lines = f.readlines()
    id2fragment = {}
    current_fragment_lines = []
    current_id = None
    previous_id = None
    for line in lines:
        if needs_order_checking:
            id_ = detecting_id_function(line, previous_id)
        else:
            id_ = detecting_id_function(line)
        if id_:
            if current_id:
                id2fragment[current_id] = ''.join(current_fragment_lines)
            current_fragment_lines = []
            current_id = id_
        else:
            current_fragment_lines.append(line)
    if current_id:
        id2fragment[current_id] = ''.join(current_fragment_lines)
    return id2fragment

# %%
FRAGMENTS_JSON_DIRECTORY = 'D:\Диплом_текстовые_квесты\Data\questbook_fragments_json'

# %%
#These quests have different format of id
exceptions = ['Колдунья и книга заклинаний.txt', 'буйвол.txt']
order_exceptions = ['Наперегонки с торнадо.txt']

# %%
not_splitted_quests = []

# %%
exceptions = []

# %%
for file in os.listdir(TXT_DIRECTORY):
    json_name = os.path.splitext(file)[0] + '.json'
    if json_name in problem_files:
        needs_order_checking = False
        fragments = split_quest(os.path.join(TXT_DIRECTORY, file), get_id4number, needs_order_checking)
        if fragments:
            json_path = os.path.join(FRAGMENTS_JSON_DIRECTORY, json_name)
            with open(json_path, 'w', encoding='utf-8') as f:
                json.dump(fragments, f)
        else:
            not_splitted_quests.append(file)

# %%
for file in ['Прорыв (v1.0).txt']:
    if file not in exceptions:
        fragments = split_quest(os.path.join(TXT_DIRECTORY, file), get_id4number, needs_order_checking=True)
        if fragments:
            json_name = os.path.splitext(file)[0] + '.json'
            json_path = os.path.join(FRAGMENTS_JSON_DIRECTORY, json_name)
            with open(json_path, 'w', encoding='utf-8') as f:
                json.dump(fragments, f)
        else:
            not_splitted_quests.append(file)

# %%
not_splitted_quests
# Out:
# []

# %% [markdown]
# Two quests are enumerated at the beginning of the same line. Let's  change the enumeration format and redo splitting

# %%
def split_enumeration_and_text(file_path, encoding='utf-8'):
    with open(file_path, encoding=encoding) as f:
        lines = f.readlines()
    new_lines = []
    for line in lines:
        id_match = re.match('\s*\d+', line)
        if not id_match:
            new_lines.append(line)
        else:
            new_lines.append(line[:id_match.span()[1]].strip()+'\n')
            new_lines.append(line[id_match.span()[1]:].lstrip(' .'))
    with open(file_path, 'w', encoding=encoding) as f:
        f.write(''.join(new_lines))

# %%
for file in set(not_splitted_quests):
    file_path = os.path.join(TXT_DIRECTORY, file)
    split_enumeration_and_text(file_path)

# %%
for file in set(not_splitted_quests):
    fragments = split_quest(os.path.join(TXT_DIRECTORY, file), get_id4number)
    if fragments:
        json_name = os.path.splitext(file)[0] + '.json'
        json_path = os.path.join(FRAGMENTS_JSON_DIRECTORY, json_name)
        with open(json_path, 'w', encoding='utf-8') as f:
            json.dump(fragments, f)
    else:
        print('file' + ' is not splitted')

# %%
exceptions
# Out:
# ['Колдунья и книга заклинаний.txt', 'буйвол.txt']

# %%
def get_id_other_format(line, id_regexp, num_tokens_before=[0], symbols2strip=None):
    stripped_line = line.strip(symbols2strip)
    tokens = stripped_line.split()
    if len(tokens)-1 in num_tokens_before:
        stripped_line = tokens[-1]
        id_match = re.match(id_regexp, stripped_line)
        if id_match and id_match.span()[1] == len(stripped_line):
            return stripped_line
        else:
            return None
    else:
        return None

# %%
exceptions
# Out:
# ['Колдунья и книга заклинаний.txt', 'буйвол.txt']

# %%
file2id_detecting_fuction = {
   'Колдунья и книга заклинаний.txt': lambda line: get_id_other_format(line, id_regexp='\d[А-Я]|\d+'),
   'буйвол.txt': lambda line: get_id_other_format(line, id_regexp='\d+[A-Z]', num_tokens_before=[1])
}

# %%
for file in exceptions:
    fragments = split_quest(os.path.join(TXT_DIRECTORY, file), file2id_detecting_fuction[file])
    if fragments:
        json_name = os.path.splitext(file)[0] + '.json'
        json_path = os.path.join(FRAGMENTS_JSON_DIRECTORY, json_name)
        with open(json_path, 'w', encoding='utf-8') as f:
            json.dump(fragments, f)
    else:
        print(file)

# %% [markdown]
# # Detect transitions

# %%
file2id_regexp = {
    'Колдунья и книга заклинаний':'\d[А-Я]|\d+',
    'буйвол': '\d+[A-Z]',
    
}

# %%
file2previous_tokens = {
    'Аргинк (A5, v1.0)': ['параграф'],
    'BB1rusKalgor': ['прочти'],
    'Black_Panther_v1.2': [r'(', r')'],
    'dogs2':[r'('],
    'Идущий на смех': ['–'],
    'fairysh': [r'('],
    'Face2face': ['(', ')', '-'],
    'FF#2 - Цитадель хаоса (a5, v1.1)': [r'('],
    'fu (v1.1)': [r'('],
     'Inspektor': [r'('],
    'Korablekrushenie': [r'('],
    'Labirint_zhdyot_vas': ['п'],
    'lw0_1.00_a4':[r'['],
    'SW4 (A5, v1.0)':['раздел'],
    'Адское болото': ['на'],
    'Алькатрас - П.Горохов': [r'('],
    'Боевые ямы Крарта': ['параграф'],
    'Большое приключение малыша Лешеньки': ['глава'],
    'Аргинк (A5, v1.0)': ['параграфу'],
     'Боевые ямы Крарта': ['параграф'],
    'буйвол': [r'(', r')'],
    'В землях орков': [r'(', 'далее', 'параграф'],
    'В поисках рождества': ['Прочти'],
    
    'Вереница миров': ['п'], 
    'Воин острого клинка':[r'(', '-'],
    'Выбор сотника': [r'('],
    'Выжить и вернуться домой': [r'('],
    'Генезис 1.6': [r'('],
    'Герой по случайности. Приключение первое': [r'('],
    'Город бешеных псов': [r'('],
    'Города Золота и Славы': ['параграф'],
    'Даманский': [r'('],
    'Демоны бездны':['на'],
    'Дом Дьявола':[r'('],
    'Емельянова__Искушение_студента': [r'('],
     'Жаброносец':[r'('],
    'За семью печатями _v1.1' :['§'],
    'Замок потерянных душ - ч1':['параграф'],
    'Замок потерянных душ - ч2':['параграф'],
    'Замок потерянных душ - ч3':['параграф'],
    'Замок потерянных душ - ч4':['параграф'],
    'Каникулы в джунглях':['страницу'],
    'Капитан Морской ведьмы': ['п'],
    'Катарсис - v1.5': [r'('],
    'Кинжалы во тьме': ['-'],
    'книга-игра Та самая игра': ['-'],
     'Колдунья и книга заклинаний': ['на'],
    'Кольцо джинна':  ['параграф'],
    'Кристал Каспли':[r'('],
    'Кровавые кости':[r'(', '-'],
     'Курортный роман': [r'(', '-', 'use_lines_of_numbers'],
    'Лабиринт страха': ['на'],
    'Лекарство от смерти 1.01': ['<', '>'],
    'Лес и трава': ['('],
    'Ловушка - часть 1 (v1.01, A5)': [r'('],
    'Ловушка - часть 2 (A5)': [r'('],
    'Лунатик': [r'(', 'то'],
    'Майкл Фрост - Чернолесье': ['на'],
    'Месть Альтея': [r'(', 'на'],
    'Меч самурая': ['на'],
    'Микрорыцарь': ['параграф'],
    'Морская лихорадка (v1.0, A5)': [r'(', r')'],
    'Морские байки (1.2)': ['параграф'],
    'Наемная убийца (v1.0)': ['на'],
    'Непредвиденный пассажир': ['<', '>'],
    'Ночь в лесу оборотней': ['страницу'],
    'Один против пламени': ['пункту', 'пункт', 'к'],
    'Одинокий волк 2 - Огонь на воде': ['на', "то"],
    'Операция Кладенец':['главу'],
    'Оружие возмездия - книга-игра': ['№'],
    'Остров крови': ['-'],
    'Остров неупокоенных': ['('],
    "Остров циклопа": ["на", "параграф"],
    "Остров чёрного колдуна":  [r'('],
    "Пиратская одиссея": ["на"],
    "Пленник чудо-дерева": [r'(', '-', '—'],
    "По воле Рима": ['-'],
    "Побег": [r'('],
    "Погоня":['-'],
    "Подземелья знака кошмаров":[r'(', '-'],
    "Подземная дорога 1.1":[r"["],
    "Притча о том, как Пич Квачо генерала спас":[r'(', '-'],
    
    "Пророчество о черной династии":['-'],
    "Наперегонки с торнадо": ['страница'],
    "Равнины завывающей тьмы (A5, v1.00)": ['на'],
    "Растревоженный Манхеттен":[r'(', '-'],
    "Резонанс (светлая версия)":['-'],
    "Роберт Стайн - Дневник сумасшедшей мумии": ["страницу", 'страница'],
    "Робинзон Крузо книга-игра": ['-', 'на', 'то'],
    "Робур2 - Город Вин 2": [r'('],
    'Рубка_драка': ['параграф'],
    'Рыцари Погибели (1.0)': [r'(', '-'],
    'Рыцарь живых мертвецов (v1.0)': ['-', 'на', 'то', r'('],
    'Саксонские войны':['параграф'],
    'Семь змей': ['(', '-'],
    'Сказание_о_Загоре': [r'(', '-'],
    'Скала ужаса': [r'('],
    'Скипетр Нижнего мира': ['параграф'],
    'Склеп вампира': ['параграф'],
    'Смертоносная тень - Часть 1 _': ['на'],
    'Спасаясь от тьмы': ['на', 'к'],
    'Спектральные сталкеры':  [r'(', '-'],
    'Тачанка - книга-игра': ['-'],
    'Темный узурпатор1': ['параграф'],
    'Точка отсчета': ['параграф', 'NEXT_WORD'],
    'Три дороги (v1.1)': [r'('],
    'Турнир юнлингов (v1.0, A5)':  [r'('],
    'Ты-удобрение для растений': ['страница'],
    'Угроза с Дикого Кладбища':['то', 'на', r'('],
    'Усыпальницы Королей':['прочтите', 'читайте', 'на'],
    'Филипп Эбли - Остров осьминогов - А5': ['пункт'],
    'Холмы Шамутанти':[r'(', '-', 'LINE'],
    'Храм ужаса': [r'(', '-', r'?'],
    'Цирк - западня': ['страница'],
    'Человекосжималки': ['страница'],
    'Шерлок Холмс 3 (без фона) v1.1':['на', r'('],
    'Школа для смельчаков':['на', '-'],
    'Эдвард Паккард - Тайна заброшенного замка': ['-'],
    'Элгар Флетч': ['прочти']
}

# %%
file2prohibited_neighbours = {
   'Fabled_Lands_6_Lords_of_the_Rising_Sun_RUS' : ['шаблов'],
    'Алдар Косе приключения безбородого обманщика v4.2': ['уровень'],
    'FF21 - Глаз дракона': ['выносливость', 'мастерство', 'удача'],
     'dzhungar_v1.0': ['+'],
    'Владыка степей (1.2.1b)': ['глоток'],
    'Вой оборотня': ['мастерство', 'выносливость', 'золотой'],
     'Воля зоны': ['репутация', "воля", "здоровье"],
    'КвестРЕЛИКВИЯ': ['='],
    'Кощеева цепь': ['сила'],
    'Наступление тьмы': ['мастерство', 'выносливость'],
    "Портал зла":['мастерство', 'выносливость'],
    "Проект1 - 3.0.1":["IGNORE_CAPS"],
    "Проклятый лес (A5, v1.0)": ['мастерство', 'выносливость', 'очко'],
    "Проклятие мумии": ['навык', 'стойкость'],
    "Робур2 - Город Вин 2": ['д'],
    'Тачанка - книга-игра': ['червонец', 'лекарство', 'выносливость', 'еда'],
    'Цыркунов__Ассасин': ['ед'],
    }

# %%
quests_with_lines_for_transitions = {
    'dafin1',
    'dq1_tlos_v1.0',
    'Face2face',
    'fftd_x1',
    'logovo',
    'Возвращение',
    'Ночь по ту сторону Смерти (A5, v1.0)''
    'Общество червей (v1.0)',
    'Один против Империи',
    'По Кровавому морю (A5, v1.00beta)',
}

# %%
#default item is a sentence
#pod
file2transition_item = {
    'BB1rusKalgor': 'line',
    'Black_Panther_v1.2': 'line',
    'dafin1': 'line',
    'dogs2':'line'
    
}

# %%
morph = pymorphy2.MorphAnalyzer()

# %%
morph = pymorphy2.MorphAnalyzer()


ecranising = {'(': '\(',
              ')': '\)',
              '[': '\[',
              '?': '\?'
             }   

unecranising = {value:key for key, value in ecranising.items()}


def check_context(position, tokens, quest_name):
    possible_previous = file2previous_tokens.get(quest_name)
    prohibited_neighbours = file2prohibited_neighbours.get(quest_name)
    
    previous_token = unecranising[tokens[position-1]] if tokens[position-1] in unecranising else tokens[position-1]
    
    pretext_is_correct = (not possible_previous) or (position>0 and (previous_token.lower() in possible_previous or morph.parse(previous_token)[0].normal_form in possible_previous))
    if pretext_is_correct:
        no_prohibited_neighbours = not prohibited_neighbours or position == len(tokens)-1 or (tokens[position+1] not in prohibited_neighbours and morph.parse(tokens[position+1])[0].normal_form not in prohibited_neighbours)
        if no_prohibited_neighbours:
            return True
        
        
def book_fragments2graph(book_fragments:dict, quest_name:str):
    G = nx.DiGraph()
    
    if quest_name in file2id_regexp:
        transition_regexp = file2id_regexp[quest_name]
        get_id = lambda x: x
    else:
        transition_regexp = '\d+'
        get_id = lambda x: int(x)
        
    for node_id, text in book_fragments.items():
        G.add_nodes_from([get_id(node_id)], fragment_text = text)
    
    
    
    possible_previous = file2previous_tokens.get(quest_name)
                                   
    for node_id, text in book_fragments.items():
        node_from = get_id(node_id)
        text = re.sub('–', '-', text)
        text = re.sub('\.', '', text)
        text = re.sub(',', ' ,', text)
        text = re.sub('\)', ' \)', text)
        text = re.sub('\]', ' \]', text)
        if possible_previous:
            for previous_token in possible_previous:
                if previous_token != '-':
                    token = ecranising[previous_token] if previous_token in ecranising else previous_token
                    try:
                        text = re.sub(token, ' '+token+' ', text)
                    except:
                        print(previous_token)
        #print(text)
        tokens = text.split()
        for i, token in enumerate(tokens):
            match = re.match(transition_regexp, token)
            if match and len(token) == match.span()[1] and check_context(i, tokens, quest_name):
                node_to = get_id(token)
                G.add_edge(node_from, node_to)
                                   
        if possible_previous and 'LINE' in possible_previous:
            lines = text.split('/n')
            for line in lines:
                tokens = [token.strip() for token in line.split() if token]
                tokens = [token[1:] if token[0] == r'\\' and len(token) > 1 else token for token in tokens]
                if len(tokens) > 2 and all([re.match(transition_regexp, token) and re.match(transition_regexp, token).span()[1] for token in tokens]):
                    for token in tokens:
                        node_to = get_id(token)
                        G.add_edges(node_from, node_to)
    return G

# %%
file = os.path.join(FRAGMENTS_JSON_DIRECTORY, 'Black_Panther_v1.2.json')

# %%
fragments
# Out:
# {'1': 'Уже совсем стемнело, и только тонкая оранжевая полоска на горизонте напоминала о том, куда ушло\nсолнце. Небольшой кораблик уверенно шел по тихому морю. А вот в одной из кают было совсем не тихо...\n— Слушай, этой девчонки нет в базе! — проговорил парень, устало откинувшись на спинку стула. — Что\nделать будем?\n— Как нет? — вскинулся второй. — Она что, из невыездных? Так какого черта мы ее на борт взяли? Ты\nчем раньше смотрел?\n— Я что, дебил, по-твоему? — обиделся первый. — Пробил я её по невыездным, со стакана отпечатки\nснял, всё путем... По всей базе гонять не стал, времени не было. А сейчас найти не могу, ее ни в одном разделе\nнет.\n— Ага, а плохому танцору яйца мешают, — хмыкнул второй и сел за компьютер. — Учись, салага!\nСпустя час первый ехидно уточнил:\n— Так что ты там говорил насчет танцоров?\nВторой неохотно признал:\n— Нету. Значит, сбой... Ладно, пиши отчет о технической невозможности идентификации, приложи\nфото и отпечатки, а заодно пошли запрос, пусть технаря пришлют. Может, удастся под это дело новый комп\nвыбить, было бы неплохо...\nДальше (52).\n',
#  '2': '(Запишите ключевое слово «ОТКАЗ»).\n— Не отдашь? Не пойдёшь? Малыш, ты не можешь меня бросить! Только не сейчас! Только не здесь! —\nЛаскес был почти жалок в своём отчаянии, и Йелл невольно усмехнулась. Чокнутый мазилка! Было бы чего\nбояться! Она подошла к Ласкесу вплотную и показала ему свои руки.\n— Ты всё еще хочешь их отобрать? Уверен, что тебе нужны такие краски? — на конце каждого её пальца\nкрасовался длинный, чуть изогнутый коготь. Йелл не удивилась, она как будто всегда знала, что они должны\nбыть именно такими. А вот Ласкес отскочил, как ошпаренный.\n— Нет? Не нужны? — продолжала издеваться Йелл. — Ну и ладно... Повезло тебе, что я добрая... Так и\nбыть, дам я тебе краски. Держи!\nКогти прошли сквозь куртку, кожу и кости, как сквозь воздух. Йелл посмотрела на бьющееся в её когтях,\nбрызжущее во все стороны светящейся кровью сердце. Потом на упавшего Ласкеса.\n— Ты чего? Держи, ну! Что, передумал? Уже не надо? Ну, как знаешь... Тогда я возьму, мне пригодится.\nИ Йелл пошла дальше по коридору, освещая себе дорогу медленно остывающим сердцем.\nДальше (60).\n',
#  '3': 'Дайс позволил себе расслабиться, из всех возможных вопросов это был едва ли не самый безопасный.\nПсы никаким образом не влияли на безумие Йелл, так что можно было говорить свободно.\n— Псы — это результат неудачного эксперимента с биологическим оружием. Они живучи, всеядны,\nпочти неуязвимы и очень редко размножаются, что позволяет держать их под контролем, но любая водная\nпреграда ставит их в тупик, к тому же они слишком плохо переносят солнечный свет... Короче, тупиковое\nисследование. Остров был лабораторией, на котором оно проводилось.\n— А потом псы вырвались из-под контроля и вы не смогли их остановить? — почти утвердительно\nспросила Йелл.\n— Слушай, ну откуда такие выводы, фильмов насмотрелась? Разумеется, ничего такого не было. Остров\nпереоборудовали для другого эксперимента, всех незадействованных организованно вывезли, и псы теперь\nслужат другой цели. Надо сказать, прекрасно справляются со своей задачей...\n— С какой задачей? Жрать всех, кто вовремя не спрятался?!\n— Строго говоря, да.\n— И зачем вам это?! Что за чокнутый эксперимент?! Как вы можете?.. — Йелл осеклась на полуслове,\nосела на кровати и заснула. Дайс тяжело выдохнул:\n— Что-то я переоценил твои силы... Да и свои тоже. Поспи, Йелл. Рано или поздно ты все узнаешь...\nДальше (91).\n',
#  '4': '— Там-там-та-там! — пропел Сай и широким жестом отодвинул дверцу шкафа. — Жаль, свадьбы у нас не\nбыло, но свадебное платье, оказывается, можно добыть даже в Городе! Нравится?\n— Это — свадебное платье? — Йелл непонимающе прищурилась на тонкую сетку, сплошь покрытую\nкружевными бабочками.\n— Ну, шкаф же белый, правильно? И платье белое, значит, свадебное. Давай, надевай. Кажется, я уже\nпонял, в чем тут фишка...\nЙелл не без труда облачилась в сетчатое платье. Оно казалось даже строгим: длинные рукава, подол до\nпола... но тут Сай протянул руку и оторвал одну из бабочек, и наряд сразу стал весьма вызывающим, если не\nсказать больше.\n— Потрясная штука, — восхищенно выдохнул Сай. — Всегда любил отрывать бабочкам крылья...\nЙелл смотрела на его непривычно хищную улыбку, и её вдруг начало мутить. Как будто она уже когда-то\nвидела таким... Но Сай не дал ей времени, чтобы вспомнить. Белые бабочки взлетали в воздух одна за другой\nи усеивали пол, а сумма на счетчике росла все быстрее...\nДальше (81).\n',
#  '5': 'Йелл побежала по улице и вскоре с радостью убедилась в правильности своего выбора: улица явно вела\nв жилые районы. И здесь было, где спрятаться. Она свернула раз, другой, удостоверилась, что её никто не\nпреследует... и пошла быстрым шагом человека, который явно куда-то спешит, но вовсе ни от кого не убегает.\nЙелл свернула в узкий — машине не проехать — проход между двумя домами и присела, чтобы отдышаться\nи подумать, что делать дальше. На корабле она думала, что первым делом найдет себе хорошего врача, она\nпрекрасно осознавала, что не сможет жить нормальной жизнью, пока не избавится от последствий того, что\nсотворили с ней Сайленс и Рок. Но как это сделать теперь, когда её разыскивают?\nДевушка тяжело вздохнула, взглянула вверх и похолодела от ужаса: на небе собирались тучи.\n— Так, все, хватит бегать! — командный голос эхом отражался от стен переулка. Йелл ошарашенно\nзавертела головой, не понимая, откуда раздаётся голос, и наконец увидела уже знакомого полицейского. Как\nего там звали... Джейк? Он медленно шел вперед, держа её на мушке.\n— У нас не ваш остров, тебя тут же отследили по уличным камерам. Район оцеплен, тебе не скрыться.\nЖиво к стенке, больше я тебя жалеть не буду.\nЙелл не слушала и не слышала его последние слова. Она слышала только далёкие отголоски грома и\nвидела только стремительно чернеющие тучи. В голове осталась только одна мысль:\n— Бежать! (8)\n— Убить! (78)\n',
#  '6': 'Сай лихорадочно копался в шкафу, вышвыривая из него всё, что попадалось под руку. В какой-то момент\nпила чуть не отсекла ему ногу, и он выронил очередную цепь прямо на неё. Пила захрипела и остановилась.\n— Ага!\nСай начал выхватывать из шкафа всё, на чем поблескивал метал и прицельно метать их в пилу, которая\nугрожала Йелл. В этой пиле механизм был посерьезнее, но Саю все-таки удалось остановить её до того, как\nпила добралась до девушки. Через пару минут Сай вывел из строя и остальные пилы, и только тут обратил\nвнимание на счетчик. Там сверкала цифра в несколько сотен.\n— А, так вам нужно было шоу, можно даже без порно? Ур-роды! — сплюнул Сай и снова полез в осточер-\nтевший ему шкаф — за ключами. Они все-таки нашлись, в дальнем ящике. Сай отстегнул рыдающую Йелл и\nпомог ей одеться.\n— Деньги давайте, сволочи. Концерт закончился! — буркнул он в потолок. В ответ на его слова дверь\nоткрылась, за ней виднелся столик с лежащей на нем пачкой банкнот. Они вышли из комнаты, невольно\nожидая еще какой-то гадости, но им позволили беспрепятственно уйти...\nДальше (81).\n',
#  '7': '(Запишите ключевое слово «РАСПЛАТА»).\n— Ты его убила? — медленно переспросил Дайс.\n— И не только его, но и всех тех людей, которых он держал там в клетках... — еле слышным шепотом\nпризналась девушка. Она тихо и медленно рассказала, как все произошло.\n— Да... — Дайсу приходилось слышать всякое, но сегодняшний день его совершенно вымотал. Слишком\nмного данных, слишком много расчетов, слишком сложная химическая смесь сейчас висела в воздухе и втекала\nв легкие Йелл... Нужно закругляться, отдых нужен им обоим, понимал он. — Слушай, Йелл, давай закончим\nна сегодня. Ты очень устала, тебе надо отдохнуть... Мы завтра договорим, хорошо?\n— Нет, не завтра! Ты мне так толком ничего не рассказал! — возмутилась Йелл.\n— Ладно-ладно, — Дайс шутливо поднял руки. — Я отвечу на еще один твой вопрос, любой. Но потом\n— спать!\nДальше (49).\n',
#  '8': '— Не подходи ко мне! И ничего не говори! — крикнула Йелл, развернулась и побежала. Джейк пожал\nплечами и выстрелил. Шприц попал в цель, девушка пробежала еще несколько шагов и упала, корчась в\nдиких судорогах, срывая ногти об асфальт, по которому застучали первые капли. К ней подбежали сразу двое\nполицейских: мокнуть не хотелось никому, так что лучше поскорее засунуть её в машину и ехать. Йелл из\nпоследних сил попыталась ударить одного из них, целясь в глаза, но промахнулась, и её рука бессильно упала\nвниз. Её быстро погрузили в машину.\n— Вот бешеная... — проговорил кто-то. — Эй, Джейк, теперь понял, почему с островными шутить не\nстоит?\nДжейк с подозрением посмотрел на говорящего:\n— Так вы что, заметили, что наручники еле держатся? Вы меня проверяли, справлюсь или нет?\n— Есть немного, — усмехнулся тот. — Да ты не думай, она же не «патрон», и мы тебя прикрывали,\nпомогли б, если что... Но ты и сам неплохо справился. Так что считай, принят в команду.\n— Проверочки у вас... — пробормотал Джейк, садясь в машину. — Ладно, поехали.\nДальше (85).\n',
#  '9': 'Первое, что поразило меня в Городе — вонь. Город смердел так, что поначалу мне казалось, что здесь\nпросто нечем дышать. А ведь привыкла потом и даже почти перестала замечать, разве что после дождя чуть\nпоприятнее было... А потом я увидела человеческие кости, валяющиеся прямо на дороге, выбитые стекла\nдомов, вздувшийся асфальт, в трещинах которого пробивалась бурая трава, и мне стало не до вони.\nНе знаю, почему я прямо там же не потеряла сознание и не закатила истерику, видимо, все вокруг было\nнастолько ужасно, что просто не казалось реальным. Было ясно только одно: на улице оставаться нельзя,\nнужно спешить в Убежище. Пока у меня есть деньги, буду сидеть там, за неделю, наверно, удастся понять, как\nздесь выживают. Составив какой-никакой план действий, я немного приободрилась, и пошла вперед.\nЯ успела рассмотреть карту и знала дорогу к Убежищу. Дальше (30).\nЯ не знала точно, куда идти, и поэтому решила для начала найти укромное местечко, чтобы изучить карту.\nДальше (59).\n',
#  '10': 'Йелл не обернулась на шуршание отъехавшей в стороны стены. Она сидела на кровати, уткнувшись лицом\nв колени и тихонько покачивалась из стороны в сторону. Дайс вздохнул и прошел внутрь, на ходу доставая из\nкармана халата гранёный шарик. Он кашлянул, чтобы привлечь внимание девушки, а потом начал говорить.\nГоворил он долго, и пустое лицо Йелл мало-помалу приобрело осмысленное выражение. В конце концов она\nвздохнула и отвернулась.\n— Он ведь мёртв, да? Тот врач, который приходил до вас? Так что вы тут делаете, вам что, жить надоело?\nДальше (98).\n',
#  '11': '— Ты... Как ты сюда попал? Что это за место? Так ты... — Йелл запнулась. Она хотела спросить, «так ты\nне умер?», но не могла выдавить из себя эти слова, слишком боясь услышать ответ.\nЛаскес напряжённо вслушивался в её голос, потом подошел поближе и заглянул в глаза.\n— Опять ты... Опять не он... Как я устал. Я не знаю, что это за место. Я не знаю, как я сюда попал. И я не\nзнаю, как отсюда выбраться! — в его голосе звенело отчаяние. — У меня совсем не осталось краски, скоро\nмне придётся бродить наугад...\nОн поднял руки, показывая их Йелл, и та увидела, что на второй руке пальцев не осталось вовсе.\n— Краски? — переспросила она. Но Ласкес её не слышал, он прикипел взглядом к её рукам.\n— Ты! У тебя ещё есть! Много! Отдай мне! Или пойдём вместе! — Ласкес смотрел на неё тем же безумным\nвзглядом, как когда-то на галерее, и Йелл охватил тот же ужас, что и тогда. Её губы зашевелились и выдавили:\n— А если не отдам? И не пойду? Мне с тобой не по пути! Дальше (2).\n— А если я отдам тебе... краску, ты оставишь меня в покое? Дашь уйти? Дальше (80).\n— Хорошо, пойдём вместе... Дальше (23).\n',
#  '12': 'Прошел месяц. Йелл уже начала забывать больницу и белую палату. Теперь у неё была новая жизнь, и\nсейчас она летела в вертолете, с усмешкой посматривая на бледных солдат, окружавших её. Операция была\nзакончена, и закончена успешно, Йелл была покрыта коркой грязи и чужой крови, от многих пованивало\nдерьмом, в кузове вертолета было значительно просторнее, чем тогда, когда они летели на задание, да и\nвертолет был уже другой... Но она была жива. И прикидывала, сколько зарубок ей предстоит сделать на ноже.\nЙелл ярко вспомнился тот день, когда началась её новая жизнь. За дверью оказалось несколько военных,\nкоторые предложили ей поступить на службу в армию. Но не просто в армию, а в совершенно особый род\nвойск. В профессиональные убийцы.\n— Понимаешь, в чем дело, Йелл, — объясняли ей. — Уже давно доказано, что человек биологически\nне способен убить человека. Пехтура обсирается перед каждым боем, у них клинит пальцы, которыми надо\nстрелять, они нарочно палят куда попало... Однако если в подразделении есть хоть один псих, способный\nубивать — он зачастую решает задачу всего взвода, всей роты в одиночку, остальные просто создают толпу...\nВ конце концов мы осознали, что люди с психопатией, позволяющей им убивать других людей — ценней-\nшее оружие тесного боя. Мы пытались брать из тюрем убийц и внедрять их в армию, но потерпели полное\nпоражение, как оказалось, большинство были «холостыми патронами», хотя они когда-то и совершили\nубийство под давлением обстоятельств или по дури, на большее их не хватало. Другим, кто был действи-\nтельно способен убивать, не хватало дисциплины... Тогда мы придумали Остров: фабрику, где создавались\n«патроны» высшего качества. Оттуда могут выбраться только те, у кого хватает ума, хладнокровия и бес-\nпринципности, чтоб не только выжить, но и узнать про наших подсадных контрабандистов, да еще и собрать\nнемаленькую сумму денег для побега. Ты прирожденная убийца, Йелл, ты умеешь и любишь это делать, Дайсу\nоставалось лишь окончательно раскрыть твою склонность. И если он справился, то ты согласишься на нас\nработать. Что скажешь?\nЙелл шагнула вперед.\n— Согласна.\nКОНЕЦ\n',
#  '13': 'Дайс сосредоточился: предстоящая работа была не из легких, наступал едва ли не самый ответственный\nмомент в ходе лечения. Йелл предстояло узнать, что именно свело её с ума...\n— Рок был псопоклонником, причем не из простых, его статус в секте был довольно высоким, ему даже\nразрешили сделать татуировку с глазом пса, ты, может, заметила? Ну, если даже и нет, не страшно. Так вот,\nв тот день он должен был провести для Сайленса так называемый обряд посвящения. Предполагалось, что\nСайленс принесет псам свою первую жертву...\n— То есть, меня? — внезапно осипшим голосом спросила Йелл.\n— Им было все равно, кого, я тебя уверяю. В принципе, они предпочитали женщин, но мужчины тоже\nсчитались вполне пристойной жертвой. Главным условием было, чтобы жертва в итоге как можно сильнее\nпахла кровью, не могла передвигаться и осталась живой до наступления ночи. Сай с Роком выполнили все\nэти условия и ушли, но Сай почему-то решил вернуться за тобой и подобрать...\n— И сектанты его не преследовали?\n— Смешно, но нет. Псопоклонники считают, что отступников псы карают сами.\n— Значит, это они меня в жертву принести пытались... — чуть слышно пробормотала Йелл. Потом\nподняла голову и неожиданно твердо произнесла. — Дайс, ты же договорил? Давай тогда закончим на сегодня,\nхорошо? Мне нужно переварить то, что ты сказал.\nДайс удивленно моргнул, но спорить не стал.\n— Хорошо, пусть будет так. Доброй ночи, Йелл.\nОн нажал несколько кнопок, отключая связь, встал и потянулся. Сзади послышались шаги.\n— Марк, ты? Ну, как прошло, по-твоему?\n— Она твоя пациентка, вот ты мне и скажи.\n— Сам же видишь, реакция хорошая. Припадка не было, отрицания не было. Восприятие болезненное,\nно в пределах нормы... Знаешь, я думаю, завтра будем выписывать. Я сегодня вечером подготовлю все бумаги\nи с утра вышлю тебе полный отчет.\n— Хорошо, Дайс. Конечно, еще немного рано, но я рад поздравить тебя с прекрасно проделанной работой.\nЭто действительно был один из сложнейших случаев за всю мою практику. Жди прибавки!\nДальше (111).\n',
#  '14': 'Дверь открылась, и на пороге появился мужчина в незнакомой, но явно военной форме. Он окинул\nвзглядом трясущуюся от волнения Йелл и хмуро сказал:\n— Выходи. Только без фокусов, хорошо? Мы тебе ничего не сделаем.\nЙелл медленно двинулась к двери, оценивая возможного противника. Сильный. На поясе дубинка, но не\nтакая, как у светлячков, и кобура непривычной формы, чересчур громоздкая. В тесной каюте против него не\nбудет никаких шансов. Надо послушаться и выйти наружу, заодно, может, удастся понять, что происходит...\nЙелл приподняла руки, показывая, что в них ничего нет, и вышла в дверь. Её тут же взяли за локти с двух\nсторон, крепко, но не слишком грубо. Яркое солнце ослепило её, и несколько секунд она стояла, смаргивая\nнабежавшие от света слёзы.\n— А почему руки свободные?\n— Может, обойдемся без наручников, а? — возразил уже знакомый хмурый голос. — У этих островных\nникогда не знаешь, на каком месте башню сорвет, вон, на прошлого надели, так он как с цепи сорвался. Зуб\nмне выбил, скотина... Девчонка тихая, да и хлипкая, тут вести-то два шага.\n— Джейк, у тебя что, еще пара лишних зубов есть? Надевай на неё наручники и не спорь.\nПарень с опаской, стараясь не защемить кожу, защелкнул браслеты на запястьях девушки. Та не отреаги-\nровала. Йелл повели к трапу, она шла, не сопротивляясь, но мысли её прыгали. Контрабандистов не видно, на\nпалубе только люди в форме. Трое здесь, один внизу, у конца трапа. Там же стоит машина. Бронированная.\nНа окнах решетки. Из машины будет уже не выбраться, это очевидно. Если бежать, то на трапе, он узкий и\nшаткий, да и мокрый вдобавок... Другого шанса не будет, но нужно ли им пользоваться? Йелл поколебалась,\nно долго раздумывать было некогда, и она решила:\n...бежать. Дальше (54).\n...дать посадить себя в машину. Дальше (44).\n',
#  '15': '— А вы будто не знаете? — недоверчиво переспросила Йелл. — Да ладно, ни за что не поверю!\n— Я знаю многое, но не все, — парировал Дайс. — Могу порыться поискать, но на это нужно время, так\nпочему бы не узнать все из первых рук?\n— Ну, почему бы и не рассказать... — пробормотала Йелл. — Дело в том, в Городе есть несколько вышек,\nв которые не могут забраться ни люди, ни бешеные псы. Очень странные здания, похожи на грибы на ножке.\nВнизу ни дверей, ни окон, только несколько панелей с кучей кнопок. Многие новички пытаются туда забраться\n— еще бы, такое первоклассное убежище — но ни у кого не получалось. А вот Ласкесу повезло — один из\nтех, кто купил у него картину, в качестве оплаты дал ключ, с которым можно было попасть в одно из зданий.\nПравда, только в одно, для остальных он не подходил, Ласкес пробовал, и я тоже...\n— Эти «грибы» и должны были служить убежищами, — вполголоса протянул Дайс. — Убежищами, в\nкоторых можно переждать происходящее внизу, пока с материка не прилетят за уцелевшими... — он замолчал,\nи навострившая было уши Йелл поняла, что больше ничего узнать не удастся. — С этим все ясно, но как так\nвышло, что вы покинули этот дом? Я знаю только о том, что происходило с вами в последние пару месяцев, и\nзнаю, что все это время вы жили, как все остальные на Острове.\nДальше (28).\n',
#  '16': 'Йелл задумалась, потом тряхнула головой:\n— Нет, не помню такого. Если и пересекалась с ним, то забыла-а... — Йелл не смогла сдержать зевок.\n— Так, знаешь, иди-ка ты спать, а? — улыбнулся Дай. — Ты же уже еле держишься от усталости. Вздрем-\nнешь немного, потом договорим?\n— Ага, от усталости... — проворчала Йелл. — Ты меня какой-нибудь дрянью опять накачал, так ведь?\n— Есть немного, — Дайс не стал врать, — но это не значит, что тебе не нужен отдых. Давай так, я отвечаю\nна еще один твой вопрос и все на сегодня. Только подумай как следует, прежде чем спрашивать.\nДальше (49).\n',
#  '17': '— Хорошо, — неожиданно легко согласился Дайс. — однако мы будем вынуждены изолировать вас от\nобщества как личность, представляющую потенциальную опасность.\nИ он исчез. Раздалось негромкое шуршание, и Йелл растерянно оглянулась по сторонам. Окно затянулось\nпластиной, которая тут же слилась со стеной так, что стало не разобрать, где оно было. Кровать уехала в\nпол. Йелл осталась сидеть посередине ровного белого куба. Потянулось странное томительное безвременье.\nЙелл пыталась хоть как-то себя развлечь, считала вслух и про себя, ходила от стены к стены, пробовала делать\nкакое-то подобие зарядки. Через неравные промежутки времени в кубе появлялась еда, время от времени\nиз стены выдвигался унитаз. Вот и все разнообразие. Девушка попыталась игнорировать унитаз и вместо\nэтого размазала экскременты по стенам. Лучше не стало, остаток «дня» она провела в жуткой вони, которая\nживо напомнила ей о Городе, а когда проснулась, стены снова сияли мягкой белизной. Через несколько то ли\nнедель, то ли дней Йелл окончательно выдохлась.\n— Ладно, я все поняла, — сказала она, обращаясь в пустоту. — Я отсюда выйду либо здоровая, либо\nвперед ногами. Давайте меня лечить, что ли... Эй, меня кто-нибудь слышит?\nРаздалось слабое шуршание, в комнате опять появились кровать и два кресла, а в одной из стен прорезалось\nокно. За окном была ночь, светила полная луна. Йелл подошла к окну, наслаждаясь уже тем, что она видит\nхоть что-то, кроме белизны. Сзади послышался укоризненный голос:\n— Йелл, я очень рад, что вы решили со мной сотрудничать, но неужели нельзя было сделать это днем?\n— Если б вы дали мне часы, я бы подождала, — огрызнулась Йелл, оборачиваясь. По взлохмаченным\nволосам и заспанному виду Дайса она поняла, что вытащила его из постели, но стыдно ей не было.\n— Итак, выкладывайте, как вы будете меня лечить?\nДальше (64).\n',
#  '18': 'Девушка изменилась в лице. Она долго молчала, стараясь побороть нахлынувший приступ паники, и в\nконце концов с трудом проговорила.\n— Я... Я не знаю.\n— Ничего страшного, так я и думал. Только не волнуйтесь, я сейчас вам все расскажу... — Дайс порылся\nв карманах и достал небольшой переливающийся шар. — Прошу вас, слушайте внимательно и ничего не\nбойтесь.\nГоворил он долго, и пустое лицо Йелл мало-помалу приобрело осмысленное выражение. В конце концов\nона вздохнула и отвернулась.\n— Я всё вспомнила... Но раз вы знаете, кто я, то что вы здесь делаете? Я же могу в любой момент взбеситься\nи убить вас. Вам что, жить надоело?\nДальше (98).\n',
#  '19': 'Йелл ничего не ответила. Несколько раз она открывала рот, словно порываясь что-то сказать, но так и не\nиздала ни звука.\nМолчание явно затягивалось, и врач уже начал проявлять признаки нетерпения, но постарался этого не\nпоказывать и мягко повторил вопрос:\n— Так все-таки, кто же вы? Как вас зовут, сколько вам лет?\nДевушка вскочила с места, да так неожиданно, что Дайс отшатнулся.\n— Я не знаю! — закричала она ему в лицо. — Я не знаю, не знаю, не знаю-у-у...\nОна расплакалась и рухнула обратно в кресло. Дайс почувствовал непривычный укол вины.\n— Я расскажу тебе, кто ты, — пообещал он. Йелл подняла голову и недоверчиво посмотрела на него:\n— А ты знаешь?\n— Пока нет, — признался он. — Но я узнаю, не сомневайся. И расскажу тебе.\nДальше (75).\n',
#  '20': 'Отправив Йелл спать, Дайс продолжил работу. Он записал всё, что услышал от Йелл, в её дело, а потом\nоткрыл общую базу и принялся за поиски Ласкеса. Много времени это не заняло, данных было предостаточно.\n— Так... «Три месяца сожительствовал с падалью женского пола, характер взаимоотношений неясен»...\nЭто она и была. Идентификацию, конечно, никто проводить не стал, до падали никому нет дела... «Погиб\nпри невыясненных обстоятельствах»... Вот здесь надо исправить, раз обстоятельства выяснились. Должен же\nбыть порядок.\nДайс немного подумав, быстро застучал по клавишам. Потом откинулся в кресле и с удовлетворением\nпосмотрел на получившийся текст: «Три месяца прожил в партнёрских отношениях с боевым патроном\n(имя: Йелл). Был убит ей же».\n— Надо выяснить, почему её записали в падаль... Это же явный боевой патрон. И раз так, теперь моя\nзадача довести её до ума и отдать в надёжные руки, пусть стреляет.\nДальше (89).\n',
#  '21': '— Практичная ты моя! — хохотнул Сай, и они вошли в сияющее кремовым кафелем помещение. Йелл\nдаже прищурилась от яркого света. «Ну, хоть тут не розовое, и то хорошо», — подумала она. Пока она\nпереминалась с ноги на ногу, Сай активно знакомился с ванной.\n— Ух ты! Джакузи с массажем! Душ! Мыло-пена-пузыри! Так, а розовых лепестков почему нет? — вдруг\nгрозно спросил он. — Какой перетрах в ванной без розовых лепестков? Ладно, переживем... Йелл, не стой\nтам, раздевайся! Ты права была, сначала помоемся, я тебе спинку потру... Я прямо человеком себя чувствую,\nа? Ты как?\nЙелл молча смотрела на счетчик. Он и в самом деле был большой, не заметить невозможно. Она сняла\nперчатки. Десять центов. Куртку. Двадцать. «Нет, так не пойдет, маловато будет!» — вдруг возмутилась она\nпро себя, и майку снимала уже «на зрителя» — медленно, дразняще, тут погладить, там плечом повести.\nМожет, получалось не очень, но счетчик попытку оценил в полдоллара. Сай заметил её манипуляции.\n— Хм, а если я тебя? Или ты меня? Наверно, круче всего будет, если порвать что-нибудь, но у нас одежды\nне так много, чтоб с этим экспериментировать...\nКогда, наконец, они оба остались без одежды, на счетчике набралась почти пятёрка.\n— А они неплохо платят! — хмыкнул Сай. — Надо будет еще разок сюда прийти! Ну что, джакузи\nя включил наливаться, давай сначала под душ, а потом ка-ак нырнём! Постой, я чего-то не понял, тут как\nвообще?.. Ты такое видела когда-нибудь?\nЙелл зашла вслед за Саем в просторную душевую кабину и осмотрелась вокруг: краны были обычные, но\nне два, красный и синий, а три: красный, желтый и белый. А вот «лейки» не было, дырочки усеивали весь\nпотолок.\n— Я в таких мылся, льет, как дождиком, здорово! — объяснил Сай, перехватив направленный вверх\nвзгляд Йелл. — Вот только непонятно, что крутить. Ладно, давай ты? Тебе какой больше нравится?\nЙелл подошла к панели и остановилась, раздумывая. Сай придвинулся поближе, его дыхание становилось\nвсё тяжелее. В конце концов, а чего ждать-то? Он обнял её со спины и начал покрывать её плечи и шею\nмелкими шутливыми укусами.\n— Решай скорее, а то съем!\nЙелл пожала плечами и решительно крутанула:\n— красный кран (110).\n— желтый кран (100).\n— белый кран (109).\n',
#  '22': 'Карта была довольно подробной, и я сразу поняла, что её лучше не терять — Город явно был на редкость\nзапутанным местом. Одни кварталы были расчерчены улицами, как по линейке, в других дома были разбро-\nсаны как попало. Да и сами дома были довольно странными, я нашла по меньшей мере два здания, в каждом\nиз которых мог бы уместиться целый квартал. Склады? Заводы? Надо бы проверить.\nНа карте ярким пятном выделялся район, помеченный как «Золотой квартал». Совсем небольшой, всего\nодна улица, вдоль которой выстроились небольшие домики, он явно имел какое-то важное значение.\nЯ поискала на карте значки, обозначающие Убежища. Искать долго не пришлось, их оказалось довольно\nмного. Еще бы понять, где я сейчас, и было бы просто замечательно... Может, вот это? «Место высадки»? Но\nдолго думать мне не дали: настала моя очередь выходить наружу.\nДальше (9).\n',
#  '23': '— Пойдём, — с явным облегчением согласился Ласкес.\nИ они пошли. Сначала настороженно, сторонясь друг друга, но развилок всё не было, и между ними\nпотихоньку, сам собой, завязался разговор. Ласкес рассказывал о живописи и истории, о древних философах\nи современных писателях, а Йелл слушала и задавала вопросы. Всё было так же, как когда-то давно, когда они\nоба сидели в мастерской, и Ласкес рисовал, а Йелл разделывала очередную собаку. Оба ожили, приободрились\nи даже начали обмениваться шутками, не замечая, что коридор так и ведёт вперёд, без единой развилки.\nНе замечая, что темнота потихоньку сереет и светлеет. Не замечая, что давящий полукруглый свод исчез и\nсменился чередой высоких резных арок... Но тут Ласкес остановился.\n— Прости меня, Йелл. Прости что не замечал тебя настоящую, что заставил тебя быть тенью своего сына.\nТы заслужила лучшего. Спасибо, что скрасила мне мои последние дни... И прощай.\nЛаскес чуть отошёл от Йелл — и его охватило светлое пламя.\n— Иди вперёд, Йелл. Там будет выход. Если ты сможешь дойти до него, то будешь свободна...\nНо Йелл не двинулась с места. Она смотрела, как огонь вокруг Ласкеса вспыхнул и погас, исчезая вместе с\nним. Она неверяще посмотрела на место, где стоял человек, когда-то заменивший ей отца, а потом рухнула\nна колени и завыла. Она выла, как умирающая волчица, а вокруг становилось всё темнее, и потолок стал\nпотихоньку опускаться, всё ниже и ниже...\nДальше (60).\n',
#  '24': '(Запишите ключевое слово «ТУМАН»).\n— Я не смогу жить без тебя... — прошептала Йелл. — Я иду к тебе, любимый...\nЕё кровь лилась, смешиваясь с кровью Сая, и она любовалась этим зрелищем.\n— Мы всегда были одним целым... И в жизни, и в смерти... — шептала она. — Я всегда буду тебя любить...\nДальше (48).\n',
#  '25': '(Запишите ключевое слово «УДАР»).\n— Я бросилась вперёд и изо всех сил толкнула его в грудь. В голове билась только одна мысль: «Я или\nменя! Я или меня!» К счастью, перила были не слишком высокими, Дайс тяжело откинулся назад, медленно,\nневыносимо медленно перевалился через перила и исчез. Снизу послышался глухой булькающий звук удара.\nЯ вдруг поняла, как же я устала... Если бы я могла, я бы упала и уснула прямо там, но мне слишком хотелось\nжить. Поэтому я поднялась и с трудом пошла по ступенькам вниз, на пол ангара выбралась почти ползком, и\nтут вонь, поднимающаяся от пола, немного привела меня в чувство. Я оглянулась увидела Ласкеса. Ударом\nему оторвало руку, она лежала немного поодаль. Живот, видимо, лопнул, под толстой кожаной курткой\nвздулся бугор вырвавшихся наружу кишок. Зрелище было мерзкое, но не более того. Он был мёртв, я жива.\nЭто было главное.\nЙелл замолчала. Дайс стучал по клавишам, делая пометки, потом поднял взгляд на девушку.\n— Ну что ж, всё ясно. Неприятная история, но тебе удалось из неё выкарабкаться. И что, держишь нож\nкак память о победе?\n— Вроде того, — с кривой улыбкой ответила Йелл. — Ну так что, вернёшь мне его?\nДальше (93).\n',
#  '26': 'По старой привычке проверив, хорошо ли ходит нож в наручных ножнах (и досадливо одернув себя: ты\nуже не в Городе, хватит бояться собственной тени), Йелл подошла к двери и нажала на ручку. Дверь не откры-\nлась. Сначала она подумала, что дверь заело, покрутила ручку так и эдак, проверила, нет ли где незамеченной\nей защелки, налегла на дверь плечом... В общем, проделала всё, что ей нередко приходилось делать по утрам в\nГороде, если удавалось проснуться первой. Но дверь не поддавалась, и Йелл начала волноваться. Она:\n— начала стучать в дверь и звать. Дальше (94).\n— решила выглянуть в иллюминатор. Дальше (68).\n',
#  '27': 'Девушка очнулась, и первое, что она почувствовала: непривычную пустоту на руке. Нож! Где нож? Ножа\nне было. Не было и кожаной куртки, а только мягкий бежевый костюм, вроде спортивного. Она осмотрелась\nвокруг. Белая комната, белые стены, белая кровать с белым бельем...\n— Свихнуться можно от такой обстановочки, — подумала Йелл. — Как меня сюда занесло?\nОна встала с кровати и обнаружила, что пол под ногами слегка пружинит. Мягкий? Она для верности\nпостучала по нему кулаком. Мягкий. Точно такими же оказались и стены, и даже потолок, до которого Йелл\nне поленилась допрыгнуть, встав на кровать. Кровать тоже оказалась довольно странной, из твердого, но при\nэтом податливого материала. Простукивать стекло в окне, за которым стучал дождь, Йелл уже не стала, и так\nпонятно, что там стоит не обычное стекло...\nВдруг часть стены уехала вбок, и в открывшемся проёме стало видно другую комнату. Там стояли стол и\nдва кресла, в одном из которых сидел незнакомый ей человек в белом халате.\n— Проходите, присаживайтесь, — пригласил её он. — Выпейте воды?\nДевушка заколебалась, не зная, что делать, но в итоге села в кресло. Дальше (95).\n',
#  '28': 'Йелл прикусила губу, помолчала немного и вдруг недовольно выплюнула:\n— Хватит мне уже «выкать», а? Я ему тут наизнанку выворачиваюсь, а он...\n— Хорошо, Йелл, как скажешь. Можно и на «ты», мне так будет даже проще с тобой работать... Но\nвсе-таки, ответь на мой вопрос.\nЙелл вздохнула:\n— Если бы это было так просто... Я, кажется, уже говорила, что Ласкес часто уходил и не брал меня с\nсобой? Иногда он возвращался особенно поздно, и каждый раз, когда это происходило, от него так странно\nпахло... Очень неприятный запах. Один раз после такой долгой вылазки он вернулся совсем без сил, почти\nперед самым появлением псов и сказал, что завтра кое-что мне покажет.\nНа следующий день он повел меня в Город. Мы пришли огромному высокому зданию вроде ангара для\nсамолетов. Я его видела и раньше, и без Ласкеса ни за что бы туда не зашла, но он потянул меня внутрь. Внутри\nжутко воняло, было даже трудно дышать, а пол был сплошь заляпан красными пятнами. Ласкес повел меня\nк узкой винтовой лестнице в углу. Мы поднимались целую вечность, не знаю, сколько десятков этажей мы\nпрошли, но у меня уже кружилась голова и дрожали ноги, когда мы наконец вышли на узкую галерею под\nсамым потолком. Отсюда можно было окинуть взглядом все здание, и когда я это сделала, то поняла, что\nпятна на полу складываются в громадную картину... Картину, нарисованную в два цвета: серый пол и красная\nкраска. Увидев её, я забыла об усталости и, вцепившись в перила, уставилась на картину.\nНа ней был нарисован ангел. Ангел, упавший с неба. Его крылья были сломаны и искорежены, он лежал,\nраскинув руки, неловко откинув голову, и с первого же взгляда было ясно, что этот ангел мертв. Но самым\nпугающим было то, что у ангела было моё лицо... Я была так растеряна, что не сразу поняла, что Ласкес что-то\nговорит.\n— ...кровь, масло и известь. Краска получается стойкая, она не выцветает десятилетиями, такой краской\nпользовались в древних храмах одной религии, последователей которой уже не осталось. Кровь и известь\nдостать было просто, с маслом пришлось повозиться, но оно того стоило... Эта картина останется здесь на\nгоды, на века, и не выцветет, не потускнеет...\n— Кто это? — спросила я, зная ответ и боясь его услышать.\n— Это мой малыш, — просто ответил он. — Мой малыш, которого я столкнул с неба... Он упал и\nразбился... Это я убил его... Убил его... Я был под кайфом, когда вернулся домой, я даже не помню, что\nслучилось... Потом мне сказали, что я толкнул его, и он ударился виском об угол стола... Когда я очнулся, он\nлежал там, так же, как лежит здесь, и только тогда я впервые увидел, что у него были крылья... Прекрасные\nсильные крылья, которые я сломал...\nПотом был суд, мне хотели дать условный срок, они не хотели сажать меня в тюрьму... Тогда я сказал, что\nесли меня не запрут, я выйду на улицу и буду убивать, пока они меня не посадят. Но они почему-то отправили\nменя сюда. Я сдержал обещание, я выходил и убивал, а кровью писал эту картину... Я...\nТут он наконец поднял на меня глаза — и его зашатало:\n— Малыш! Это ты?! Нет, это не можешь быть ты, ты лежишь там! Ты лежишь там!!! Ты должен лежать\nтам!!!\nЯ была в ужасе. Картину освещали включенные Ласкесом софиты, но на галерее стоял полумрак, он не\nвидел моих глаз. От страха у меня перехватило дыхание. А Ласкес приближался ко мне, он твердо решил\nсхватить меня и сбросить вниз. Оставались считанные секунды, и я...\n...развернулась и бросилась вниз по лестнице (36).\n...попыталась заговорить с ним (58).\n...бросилась вперед, чтобы самой столкнуть его вниз (25).\n',
#  '29': 'На следующий день Йелл проснулась от негромкого стука в дверь. Стук? Дверь? Она вскочила и поспешила\nоткрыть. За порогом стоял Дайс с букетом цветом.\n— Поздравляю, Йелл. Ты признана здоровой и мы решили тебя выписать. Сегодня еще поживешь здесь,\nпереночуешь, мы уладим кое-какие формальности, оформим тебе документы — а завтра с утра ты будешь\nсвободна. Эй, постой-постой, подожди обниматься, ты же меня задушишь! Дай хоть букет положу!\nЧерез пару минут Йелл наконец пришла в себя и выжидающе уставилась на Дайса.\n— И что теперь?\n— Теперь переоденься и пойдем, погуляем в парке. Я тебе все расскажу.\nДень прекрасный, солнечный, они неспешно брели по парку, Йелл засыпала Дайса вопросами, на которые\nтот обстоятельно отвечал.\n— Было решено выделить тебе компенсацию, она небольшая, но на первое время тебе хватит, сможешь\nнайти работу или начать учиться. С жильем тоже проблем не возникнет, мы нашли твою прежнюю квартиру\nи обменяли её на другую...\n— Постой, — впервые за день в глазах Йелл заплескалась тревога. — Ты так ничего и не рассказал мне о\nмоей прошлой жизни! Я так и не знаю, что было со мной до острова, а если я буду жить на новом месте, то и\nне вспомню!\n— Йелл... — Дайс мягко сжал её ладонь и заглянул прямо в глаза. — Поверь, тебе не нужно это знать.\nНо Остров никто не попадает просто так, и ты — не исключение. Ты заработала себе право на новую жизнь,\nпользуйся им. И не пытайся узнать, что случилось, я говорю тебе как врач — твоя психика этого не выдержит,\nты снова скатишься в безумие, и на этот раз уже навсегда. Живи, Йелл. Просто живи. И будь счастлива.\nДальше (56).\n',
#  '30': 'Я посмотрела на солнце, сориентировалась по сторонам света и уверенно зашагала вперед. Потом сооб-\nразила, что не стоит так открыто шагать по улице и крадучись пошла вдоль стены, осторожно заглядывая\nза каждый угол, прежде, чем повернуть или выйти из-за здания. Было очень жарко, душно... и ужасающе\nтихо. Пожалуй, тишина и пугала больше всего. Где все люди? Где те, кто выходил до меня? Они же тоже\nдолжны двигаться примерно в том же направлении, и далеко уйти они не могли. В конце концов, даже если\nмы разминулись, где голуби? Крысы? Ну хоть кто-нибудь живой? Словно в ответ на мои мысли, прямо над\nмоим ухом раздался нестерпимо свербящий звук. Я обернулась, и увидела на стене зеленую цикаду. Цикада\nгремела так, что у меня заломило в висках, но я все равно была ей рада.\nУже значительно позже я узнала, что в Городе выживают лишь люди (если, конечно, им повезет) и насеко-\nмые: всех остальных съедают псы, которые умудрились истребить даже крыс.\nЗасмотревшись на цикаду, оглушенная её пением, я не услышала шаги за спиной и заметила чужое присут-\nствие только тогда, когда на стену упала чья-то тень. Я успела только обернуться и увидеть кулак, летящий\nмне в лицо, а потом меня отбросило к стене и впечатало в неё. Цикада замолчала навсегда...\nДальше (114).\n',
#  '31': 'Коридор петлял из стороны в сторону, двоился и троился, но Йелл, раз приняв решение, продолжала\nидти по стрелкам, и каждые несколько стрелок она находила по ногтю. Йелл начала уставать от ходьбы, когда\nза очередным поворотом она вдруг увидела развилку — а на ней человека. Быстро нырнув обратно за угол,\nЙелл осторожно выглянула и стала наблюдать. Человек стоял к ней спиной и, похоже, мучительно размышлял,\nкуда же ему идти. В конце концов он подошел к стене одного из развилков и поднял руку. Только тут Йелл\nзаметила, что у него на руке был всего только один палец, мизинец, а от безымянного остался лишь маленький\nогрызок. Этим огрызком мужчина и стал водить по стене, оставляя на ней светящийся след. Палец стирался,\nкак карандаш, и после пары штрихов сточился совсем. Вздохнув, мужчина резким движением скусил ноготь с\nмизинца — будто сорвал колпачок с тюбика — и закончил стрелку.\nЙелл не смогла сдержать возглас, и человек обернулся на звук. Это был Ласкес.\nОба застыли, узнав друг друга. Оба разрывались между желанием заговорить и убежать. И Йелл...\n...побежала (60).\n...сделала шаг вперёд и заговорила (11).\n',
#  '32': '— Откуси себе язык, Йелл. Это одна из немногих травм, с которыми мы не работаем, слишком много\nвозни с восстановлением речи, а немая ты нам не нужна, даже если выживешь снова. Откуси себе язык, Йелл,\nесли хочешь умереть навсегда... И если у тебя на это дури хватит.\n— Дайс, вы обвиняетесь в преступной халатности и неоднократном подстрекательстве к самоубийству.\n— С чего это неоднократном-то?\n— Ваша жена, Дайс. Да, когда Илла покончила с собой, вы были в служебной командировке, но при\nваших профессиональных навыках данный факт не обеспечивал вам алиби. Было проведено внутреннее\nрасследование, по результатам которого вы были признаны виновным, однако дело положили в ящик до\nвозможного рецидива, тут вы были нужнее. Теперь, когда ваша вина доказана повторно, у нас нет причин вас\nщадить. Вы отправляетесь на Остров, Дайс. Правила вам известны, пожалуй, лучше, чем кому бы то ни было.\nЕсли вы сможете вернуться, возможно, мы еще увидимся.\nДайс прикрыл глаза... и вдруг почувствовал, как его губы сами собой раздвигаются в хищной улыбке.\n— Мы еще увидимся, Марк. Непременно увидимся.\nКОНЕЦ\n',
#  '33': '— Извини, но я не принимаю твой отказ, — жестко сказал Марк. — В последнее время ты стал чересчур\nразборчивым и ведешь слишком мало пациентов. Все документы уже оформлены на тебя, и если ты хочешь\nполучить повышение раньше, чем через пять лет, то пойдешь и будешь с ней работать.\n— Ты всегда умел уговаривать, — усмехнулся врач. — Хорошо, я исправлюсь. Её уже привезли?\nДальше (27).\n',
#  '34': '— Ушла? — уточнил Дайс. — Но он же сам тебя попросил?\n— Я тогда еще не настолько зачерствела, чтобы взять и убить беззащитного!\n— Тогда? А сейчас?\nЙелл досадливо мотнула головой:\n— Зачем ты спрашиваешь всякую ерунду? Ты же сам знаешь ответ!\n— Ну да, знаю... Извини. В общем, ясно, что с тобой произошло, давай вернемся к тому, что я хотел\nрассказать.\nДальше (13).\n',
#  '35': 'Йелл улыбнулась:\n— Ой, с ножом была целая история... В общем, Ласкес был художником. Ничего себе, правда? Но он\nочень неплохо устроился: продавал картины в золотой квартал, брали хорошо, там были ценители... Ну, или\nперекупщики, какая разница. На материке всегда найдется чокнутый коллекционер, который захочет работу\nхудожника из Города. Платили кто деньгами, кто едой, один чудик даже помог с жильем: подобрал код к\nодному из запечатанных домов Города и подарил его Ласкесу. Там-то мы и жили, там и мастерская его была...\nТак вот, про нож. Буквально через неделю после того, как я поселилась у Ласкеса, ему заплатили собачати-\nной! Как сейчас помню: поднимается он по лестнице и тащит с собой собачью тушу с отрубленной головой...\nКрасивая псина была, ухоженная, явно породистая... Потом это еще не раз происходило, но в первый раз я\nиспугалась. В Городе очень быстро привыкаешь к людским трупам, но собачий как-то выбил меня из колеи. А\nкогда Ласкес это заметил, он попросил меня разделать собаку на мясо. Нет, он не хотел меня так наказать\nили помучить — просто понимал, что если я не наращу себе «шкуру» потолще, то не выживу. Я тоже это\nпонимала, поэтому взялась за дело. Крови, кстати, почти не было, но я все равно вся перепачкалась и изму-\nчилась, пока ее разделала, шкуру снять оказалось самым легким... А нож, которым я это делала, Ласкес мне\nподарил, сказал, это было мое «боевое крещение». Шутил, конечно. Но потом выяснилось, что он неплохо\nвладеет приемами ножевого боя, он меня многому научил... Ножны, кстати, он сам сделал, из собачьей же\nкожи. Удивительный человек был, столько всего умел...\nОна погрустнела и пару секунд помолчала, вспоминая что-то свое, но потом резко тряхнула головой и\nпродолжила:\n— Поэтому я и хочу этот нож обратно, он много раз меня выручал! Да и Ласкеса я не хочу забывать,\nнесмотря ни на что...\nДайс задумался: стоит ли попросить Йелл перейти к развязке истории? Или лучше дать ей рассказать\nпобольше подробностей? Какой выбор будет более щадящим для психики Йелл, этой живой гранаты, готовой\nвзорваться в любую секунду? Понятно, что сейчас он в безопасности, но лишний срыв явно не пойдет ей\nна пользу... Копаться в базе и искать дело Ласкеса, кем бы он ни был, времени нет, придется положиться на\nинтуицию. В итоге Дайс спросил:\n— Так где вы все-таки жили? Расскажите мне про эти «запечатанные дома». Дальше (15)\n— Как вышло так, что вы c Ласкесом разошлись? Я знаю только то, что в последние пару месяцев вы\nобъединились с Сайленсом, но ничего из того, что происходило до этого. Дальше (28).\n',
#  '36': 'Я не знаю, каким чудом я слетела по лестнице вниз, не переломав себе рук и ног. Ласкесу, который\nрванулся за мной, повезло гораздо меньше, он оступился и упал. Я слышала его вопль, слышала стоны, но\nслишком боялась вернуться назад...\nС тех пор я его больше не видела. К счастью, я уже довольно хорошо знала Город и, благодаря урокам\nЛаскеса, к вечеру у меня была не только спасительная десятка, но и запас на пару дней вперед... Поэтому мне\nначхать на то, что Ласкес был психом. Он спас меня, и его нож, его подарок спас меня, и я хочу его вернуть!\nДальше (93).\n',
#  '37': '— Малыш, ты почему меня не подождал? Я же просил... — голос осекся, и я, наконец, подняла глаза.\nПередо мной стоял рослый и крепкий мужчина, но лицо у него было жутко перекошено гримасой боли.\nНаконец, он справился с собой и перевел дыхание.\n— Глаза серые... — проговорил он. — Ты кто? Как тебя зовут?\n— Йелл, — хмуро ответила я. — А ты Ласкес? Что, обознался? Ну извини, я не напрашивалась, чтоб мне\nпомогали...\nОн медленно кивнул.\n— И голос другой... Ты — девушка, да?\nЧерт, надо б как-то побыстрее отрастить волосы, подумала я тогда. Раздражает уже, что все принимают\nменя за парня. На редкость глупая мысль была, как я сейчас понимаю. Тем временем Ласкес окончательно\nпришел в себя и, очевидно, принял какое-то решение.\n— Послушай, пойдем со мной, а? Я тебя не трону, ничего тебе сделаю... Тебе не выжить без помощи, ты\nже уже наверняка это понимаешь... — последние слова прозвучали почти умоляюще.\nУ меня не было ни денег, ни малейшего представления о том, как выживать дальше. Мне просто пришлось\nсогласиться и надеяться на лучшее.\nДальше (96).\n',
#  '38': '(Запишите ключевое слово «ВЫГОДА»).\n— У меня был только нож, и я не придумала ничего умнее, чем перерезать ему горло. Убивать с одного\nудара я все равно не умела, так хотя бы получилось не очень долго... Но не так уж сложно это было, вот\nпотом...\n— Ты в самом деле решила попробовать найти золото? — уточнил Дайс.\n— Ну а зачем я его убивала-то, по-твоему? Вони было, меня чуть не вывернуло. В Городе и так все время\nвоняет, но свежие кишки воняли гораздо круче... Грязная была работа, сначала я пыталась прощупать кишки,\nчтоб не вскрывать все подряд, потом вспомнила, что он эти кольца еще и ломал... Короче, перемазалась вся,\nпока нашла, меня даже в Убежище не сразу пустили, хотя тамошние хозяева ко всему привыкли. С месяц на\nто золото жила, немного, но кто б мне за него настоящую цену дал...\n— В общем, ясно все с тобой, — усмехнулся Дайс. — Ладно хоть, что он не соврал. Давай теперь я тебе\nрасскажу, что хотел.\nДальше (13).\n',
#  '39': 'Йелл сидела на деревянной ограде, окружающей поле для выгона лошадей, и беззаботно болтала ногами.\nОна уже отъездила тренировку, и теперь просто отдыхала, наслаждаясь солнцем и любуясь гарцующими\nлошадьми. Мимо неё прошла пара: мужчина с на удивление правильными, почти аристократичными чертами\nлица, и девушка с короткими золотистыми волосами. Мужчина что-то сказал и мягко почесал девушку за\nухом, та рассмеялась, потерлась головой о его плечо, и оба отправились к конюшне.\nЙелл улыбнулась, глядя на странноватую, но явно влюбленную парочку, но потом нахмурилась. Она\nдостала из нагрудного кармана затертую донельзя визитку и сотовый телефон. Посмотрела на экран: да,\nсегодня ровно год... Она вздохнула и задумалась, вспоминая, что было год назад.\nДайс проводил её до стоянки, где её ждало такси. Она долго кусала губы, не решаясь выдавить вопрос,\nкоторый мучил её весь день, но тянуть было уже некуда.\n— Послушай, а мы... Мы еще увидимся?\nДайс посмотрел на неё с мягкой, чуть снисходительной улыбкой.\n— Девочка моя... Ты ведь не думаешь, что влюбилась в меня, правда?\nЙелл вспыхнула и открыла рот, чтобы начать протестовать, но он жестом остановил её.\n— Йелл, такое случается сплошь и рядом, я прекрасно знаю все, что ты скажешь... Но поверь мне, тебе\nэто только кажется. У тебя впереди новая жизнь, ты меня очень скоро забудешь... Давай договоримся, — он\nпорылся в кармане и достал визитку. — Это мой личный номер. Если через год тебе покажется, что ты все\nеще хочешь со мной встретиться, позвони.\nЙелл еще раз вздохнула и посмотрела на визитку. А потом...\n...набрала номер. Дальше (84).\n...порвала визитку пополам. Дальше (74).\n',
# ...
#  '102': '(Запишите ключевое слово «ПРОЗРЕНИЕ»).\nЙелл смеялась и не могла остановиться.\n— Так тебе и надо! Идиот! Урод! Кретин! Я из-за тебя тут чуть не сдохла! Ненавижу тебя! Могла бы —\nеще раз убила бы!\nОна соскочила с кровати, напоследок еще раз пнула труп Сая и пошла к открывшейся навстречу ей двери.\nЗа дверью её ждали деньги и свобода...\nДальше (61).\n',
#  '103': 'Девушка съежилась на кровати:\n— Тогда я и сама этого не знала... И не знала этого еще очень долго. Знаете, он никогда не звал меня по\nимени, только «малыш». Я не знала, к кому он обращается, кого он видит на моем месте, но мне было жалко\nего, и мне было слишком страшно, чтобы спросить.\nА потом он как-то раз пришел домой, а я спала на полу. Я говорила, что мы с Ласкесом жили не в\nУбежище? У него был отдельный дом, громадный и при этом совершенно защищенный от псов, просто\nпотрясающе... Но он был не из золотых, нет... Этот дом ему подарили за картину, вернее, не сам дом, а код к\nнему. В Городе было несколько таких странных домов, туда без кода было не попасть, а у Ласкеса код был...\nДайс понял, что Йелл почти бессознательно уводит разговор в сторону, стараясь замять болезненную\nтему, но допускать этого явно было нельзя, сейчас надо было идти до конца. Он нажал пару клавиш, выпуская\nв воздух мягкое успокоительное, позволил Йелл еще несколько минут болтать, о чем вздумается, а потом\nмягко напомнил:\n— Так вы говорили, что спали, когда он пришел домой. И что было дальше?\nЙелл вздрогнула, вспомнив, от чего они ушли. Потом вздохнула, собираясь с силами и продолжила\nрассказ:\n— Устала и просто уснула, так вышло, я не хотела его пугать. Но он решил, что я умерла, и схватил меня, и\nтряс... В общем, все было так же, как в тот день, когда мы встретились. А потом он сел рядом и начал говорить\nкуда-то в пустоту, не глядя не меня. Я замерла и слушала...\n— Знаешь, когда Мита ушла, я чуть не рехнулся. Точнее, я в самом деле рехнулся, просто тогда еще не до\nконца. Она бросила на меня нашего сына, надо было как-то жить... С отчаяния я взялся за кисти — и у меня\nпрорезался талант. Настоящий талант, мои картины стали покупать, у меня были выставки... Да, меня знали\nтолько в узких кругах, но знали хорошо. Денег хватало нам обоим, и мне, и моему малышу... Но недолго,\nменя хватило всего лет на десять... Я быстро исписался, не знал, что делать, и в итоге нашел вдохновение в\nнаркотиках. Когда я рисовал под кайфом, то создавал шедевры... Потом сын узнал, он был в ужасе, он всё\nпытался убедить меня бросить это дело, найти обычную работу, говорил, что будет содержать нас обоих,\nпока я буду переучиваться... Такой славный мальчик у меня вырос... Знаешь, когда я тебя увидел, ты была так\nпохожа на него... Ты так же лежала, раскинув руки сломанными крыльями, как он тогда...\n— Так вы заменили ему сына? — спросил Дайс. Йелл мотнула головой:\n— Если бы заменила... Я стала для него его сыном, он не видел меня, он видел его на моем месте... Ну\nконечно, ничего хорошего из этого не вышло...\nДальше (28).\n',
#  '104': '— Я и не собиралась уходить из того дома... Так почему же я ушла? — в голосе Йелл зазвучала растерян-\nность, почти испуг. — Я не помню...\nДайс вздохнул. Они оба слишком устали, чтобы проводить сейчас сеанс гипноза. Обоим нужен отдых.\nОн уже собирался сказать это Йелл, как та вдруг начала говорить, сначала медленно, а потом все быстрее и\nбыстрее:\n— Помню... Помню. Я пришла к нашему дому, было уже поздно, я весь день пыталась добыть еды, но\nне получалось, не везло. Вернулась почти к закату. Ввела пароль на панели. Дверь не открылась. Меня не\nвпустило. Там была надпись: «Срок действия пароля истёк». Меня не впустило. Не впустило. У меня не\nбыло денег. Не было времени. Скоро появились псы. Я бежала, но они догнали меня и повалили. Они рвали\nменя на части. Они сожрали меня заживо. Сожрали заживо. Сожрали заживо!!!\nЙелл дико вскрикнула и забилась в судорогах. Откуда-то раздался тревожный зумм, одна из стен раскры-\nлась и в комнату ворвались люди: Дайс вызвал помощь. Он быстро описал обстановку, и реанимационная\nкоманда принялась за дело. Дайс оставался с ними до тех пор, пока ситуация не пришла в норму, и только\nпотом отключил связь. Йелл осталась лежать на кровати, погруженная в глубокий медикаментозный сон...\nДальше (47).\n',
#  '105': 'Дайс успокаивающе улыбнулся:\n— Это уже не твоя забота, да и не моя, строго говоря. Кому нужно, допросят и доберутся, какой бы он\nтам ни был психованный гений, одиночке против регулярных войск не выстоять.\n— Регулярных войск? Так вы — военные?\nДайс прикусил язык, но Йелл схватывала на лету.\n— Молчишь, значит, я права. Зачем военным наш Город? Это вы его организовали? Зачем?\nДайс предостерегающе поднял ладонь.\n— Так, Йелл. Ты поймала меня на слове и я не буду врать, что это не так. Давай договоримся, ты сейчас\nможешь задать еще один вопрос, только один, я постараюсь на него ответить, а потом ты пойдешь спать.\nХорошо?\nЙелл медленно кивнула, и Дайс улыбнулся про себя: политика честности себя оправдывала, Йелл явно\nсразу поверила его словам.\nДальше (49).\n',
#  '106': 'Сай заколебался, его как будто что-то беспокоило.\n— Точно черный? Ну ладно, сейчас что-нибудь придумаю...\nСай широко отодвинул дверцу шкафа, и Йелл передернуло: в шкафу были веревки, плетки, ошейники и\nнаручники, сплошь черное и красное, кожа и металл. Сай хмурился:\n— Не нравится мне это... Хотя... Вот, ничего штучка?\nОн выудил из глубин шкафа наручники, обшитые белым мехом, и осторожно пристегнул одну руку Йелл\nк решетке кровати:\n— Ты как? Нормально себя чувствуешь? Голова не кружится? Никаких... ассоциаций?\nЙелл непонимающе взглянула на него:\n— Нет... А ты чего так переживаешь? Все в порядке, я не против, даже любопытно. А там только одна\nпара? Вторую руку не будешь приковывать?\nВ шкафу нашлась и вторая, и вскоре кровать уже ритмично поскрипывала. Всё шло хорошо, пока к скрипу\nне добавился еще один звук.\n— Сай, что там так мерзко жужжит?\nСай обернулся на звук, побледнел и спрыгнул с кровати.\n— Там пила!!!\n— Что?!\nЙелл с трудом приподняла голову и тоже увидела пилу. Она медленно продвигалась вперед от подножия\nкровати и как раз должна была распилить Йелл на половинки. Цифра на счетчике резко увеличилась сразу на\nдесятку.\n— Сай сними наручники! Отцепи меня! Сай!\nСайленс метнулся к наручникам, но...\n— Йелл!.. Они настоящие!.. Нужен ключ!..\n— Так ищи! Скорее!\nСай дернулся к черному шкафу, но тут шум усилился, и из стен и пола вынырнуло еще несколько пил.\nСай бешено крутил головой, не зная, что делать, и в конце концов решился.\n— Он открыл дверь и выбежал из комнаты (45).\n— Он подбежал к шкафу и начал искать ключи (6).\n— Он подбежал к Йелл и начал пытаться сломать прут кровати (43).\n',
#  '107': 'Йелл побежала вдоль берега, но очень быстро поняла свою ошибку. Дорога, ведущая вдоль берега, была\nпрямой как стрела, и сворачивать с неё было некуда, с одной стороны шумело море, с другой был не слишком\nвысокий, но почти отвесный склон. Замечательные условия для легкой утренней пробежки, но не для побега.\nЙелл устремилась вперед с силой, какую может дать только отчаяние, она бежала так, словно сами бешеные\nпсы снова подгоняли её своим диким лаем... Послышался шум мотора. Машина без труда догнала её, из окна\nвысунулся полицейский и выстрелил почти в упор. Йелл пробежала еще несколько шагов на заплетающихся\nногах, а потом рухнула на дорожку, ободрав щеку. Полицейские закинули её в машину и переругиваясь\nмежду собой, расселись по местам.\n— Джейк, это ты на неё наручники надел, а застегнуть забыл? Так вот, имей в виду, если она там обгадится\nс этой дряни, убирать будешь ты!\nДальше (85).\n',
#  '108': '(Запишите ключевое слово «МИРАЖ»).\n«Если я умру, я проснусь! Если умираешь во сне, то обязательно просыпаешься!» — подумала Йелл — и\nрешительным движением провела по горлу. Кровь хлынула странным светящимся потоком и почти сразу\nвпиталась в каменный пол. Йелл вдруг увидела себя со стороны. Рок-Сай по-прежнему крепко держал её\nтело, он разговаривал сам с собой, повторяя все реплики того жуткого вечера. Не похоже, что он вообще\nзаметил, что держит труп. Йелл непонимающе смотрела вниз.\n«Это я так умерла? Душа вылетела из тела, и всё? Почему я не просыпаюсь? Почему?!» — она попыталась\nсделать хоть что-нибудь, но не смогла даже отвернуться. А тем временем Сай и Рок, наконец, разделились\nнадвое, и Йелл заново увидела и услышала всё, что произошло тем вечером, когда она сошла с ума...\nДальше (60).\n',
#  '109': 'С потолка полилось что-то белое. Логично, подумала Йелл, белый кран — белая вода... А всё-таки, что\nэто за дрянь? Сай тоже явно озадачился этим вопросом, он поймал на ладонь несколько капель, понюхал их,\nа потом решительно слизнул.\n— Молоко! Слушай, да тут даже непонятно, кто кого обслуживает, мы их или они нас! Высший разряд,\nоднако! — тут улыбка Сая стала ещё шире. — А знаешь, у меня идея! Иди-ка сюда!\nОн прислонился к стенке и заставил Йелл опуститься на колени.\n— Давай так! Ты даже вкус почувствовать не успеешь, проглотишь и сразу запьешь!\nЙелл не стала возражать. В конце концов, за минет наверняка заплатят больше, чем за простой секс, а\nесли сделать это сейчас, то потом Сай, может, не скоро начнёт снова настаивать. Йелл всегда неохотно это\nделала, даже ради Сая, им было негде толком помыться, и от него всегда так пахло... Скоро Сай удовлетво-\nренно вздохнул, тёплые белые струи смешались во рту Йелл, и она поспешила черпнуть с пола еще молока,\nчтобы окончательно смыть неприятный вкус. Они глянули на счётчик и пошли в джакузи: сумма набежала\nпорядочная, но почему бы её еще немножко не увеличить, если есть силы и желание?\nДальше (81).\n',
#  '110': 'С потолка полились теплые темно-красные ручейки и Йелл не смогла удержать вопль:\n— Кровь!!!\nВ Городе она видела всякое, но стоять под кровавым душем — это было уже слишком. Она как ошпаренная\nвылетела из душа... и только тут поняла, что Сай и не думает вылезать. Наоборот, он стоял под бордовыми\nструями с улыбкой от уха до уха, а потом открыл рот и подставил его под ручеек потолще. У Йелл к горлу\nподкатил комок. Как он может?! Что с ним, он сошел с ума? Йелл зашаталась, почти теряя сознание, перед\nглазами поплыли странные картины: дождь, гроза, кровь... Но тут Сай, наконец, обернулся.\n— Йелл, иди сюда! Это не кровь, это гора-аздо лучше! Ты принюхайся!\nДрожащая Йелл потянула носом...\n— Вино?\n— Ага. Так себе пойло, разбавленное, но с чего бы им на нас хорошее тратить? Нет, нам сегодня точно\nвезет. Выпьем, да еще и заработаем. Жаль, закуси нет, а мы почти не ели... Да иди ты уже сюда!\nСай поймал Йелл за руку и рывком втащил под душ. С отвычки, на голодный желудок, он быстро опьянел\nи был с ней гораздо грубее, чем обычно. Впрочем, Йелл было наплевать, вино и ей сразу ударило в голову и\nприглушило боль...\nДальше (81).\n',
#  '111': 'Есть ли у вас следующие слова: «ЖЕРТВА», «УДАР», «ОТКАЗ», «ПРОЗРЕНИЕ», «РАСПЛАТА»,\n”ВЫГОДА”?\nЕсли есть два или больше, перейдите на (82).\nЕсли есть один или меньше, перейдите на (29).\n',
#  '112': 'Дайс просматривал свежую сводку новостей.\n— Вот она... — пробормотал он вслух и начал читать статью с громким заголовком «Героиня спасает отряд\nценой собственной жизни». — Героиня... Да ей наплевать было на вас всех. Она всё время разрывалась между\nдвумя страстями, ей хотелось убивать и умереть. Ну что же, мы дали ей такую возможность. Предложили ей\nработу в горячей точке, обучили и отправили на смерть. И она с радостью ухватилась за данный ей шанс... —\nДайс выругался сквозь зубы и отшвырнул газету.\n— Эй-эй, потише! — раздался веселый голос, и в кабинет вошел Марк. — Чего бесишься? — Он поднял\nгазету. — А-а, ясно все с тобой.\n— Собачья у нас работа, Марк... Мы берем убийц, выбираем лучших из них — и отправляем убивать\nдальше. Мы даже не пытаемся дать им какую-то альтернативу в жизни, наоборот, вытаскиваем их худшие\nстрасти наружу, потому что именно так они становятся совершенным оружием... Марк, тебя самого от себя\nне тошнит, а?\nМарк сел напротив.\n— Дайс, ты забыл только одно. Психопаты — не люди. Человек не способен хладнокровно убить другого\nчеловека, в нас это заложено природой. Ни ты, ни я не способны убивать безнаказанно для себя, даже если\nкому-то из нас придется это сделать из самозащиты, это оставит на психике нестираемый след... А она убивала\nлегко и свободно. Дайс, не валяй дурака. Она умерла счастливой, если такие, как она, вообще могут быть\nсчастливы, избавила мир от себя, да еще и спасла не один десяток людей, хотя это получилось скорее случайно...\nЕзжай домой, Дайс, отдохни. Завтра будет новый день и новые пациенты...\nКОНЕЦ\n',
#  '113': 'Если у вас есть слова «УДАР» и «ЖЕРТВА», то перейдите на (20).\nЕсли есть только одно из этих слов или нет ни одного, перейдите на (89).\n',
#  '114': '— Малыш! Малыш, что с тобой? Малыш, очнись! Ответь мне! Нет, не надо, только не снова... Ну очнись\nже...\nЯ слышала этот срывающийся мужской голос, но мне было слишком плохо, чтобы я могла на него как-то\nреагировать. В конце концов меня подняли и куда-то понесли. Сопротивляться я не могла, так что мне\nоставалось только надеяться на лучшее. А потом я снова отключилась...\nОчнулась я утром, в большой комнате, выстланной жесткими матрацами. Часть матрасов была занята\nспящими людьми, другие были свободны. Я не имела ни малейшего представления о том, как я сюда попала,\nи никто не обращал на меня внимания. Я проверила карманы — они были пусты. Все деньги, карта — все\nисчезло... Что же мне делать дальше? Я совсем растерялась, и тут мне на плечо опустилась чья-то рука. Я\nобернулась и увидела щуплого мужичка с бегающими глазами.\n— Очухался? Тебя вчера Ласкес приволок, просил передать, чтоб ты его тут подождал, он утром придет.\nЯ б на твоем месте так и сделал, он тебе жизнь спас, по ходу...\n— Я не парень! — огрызнулась я.\n— Девчонка? А что бритая? Из новеньких? Ну, тогда тебе вдвойне повезло.\n— В чем это мне так повезло-то?\n— Ну, видимо, понравилась ты ему чем-то, раз он тебя на своем горбу в Убежище приволок. Будешь\nумницей — проживешь подольше. У нас тут бабе в одиночку долго не протянуть, а Ласкес мужик хороший,\nпо рукам не пустит.\n— Хороший?! А где мои деньги тогда?!\n— Не знаю... Может, он забрал, может, тебя кто обчистил, пока спала...\nЯ пристально посмотрела ему в глаза, но спрашивать, а не он ли и обшарил мои карманы, смысла не было:\nвсе равно же не признается.\n— Хорошо, дождусь я этого Ласкеса... Надо же хоть спасибо сказать. Дальше (50).\n— Да пошли вы оба: и ты, и этот Ласкес! — зло сказала я и пошла к выходу. Дальше (72).\n',
#  '115': '(Запишите ключевое слово «ИНТЕРЕС»).\n— Вот и прекрасно, — просиял Марк. — Её уже привезли, пойдешь, пообщаешься?\n— Нет, сначала вытрясу из военных побольше данных, в конце концов, они заинтересованы в ней гораздо\nбольше нас, должны пойти навстречу.\n— Ну, хорошо, Дайс, работай.\nОн еще раз просмотрел куцее досье, а потом разослал несколько писем. Пациентку предстоит усыпить\n(только не теми варварскими средствами, которые используют военные, а помягче), подлечить её физиче-\nские травмы, а потом уже заниматься душевными. Дайс был прекрасным психиатром и любил работать с\n«патронами», но тут спешка была явно ни к чему.\nДальше (27).'}

# %%
file = 'dogs2.json'
quest_name = os.path.splitext(file)[0]
fragments_path = os.path.join(FRAGMENTS_JSON_DIRECTORY, file)
fragments = json.load(open(fragments_path, encoding='utf-8'))
quest_graph = book_fragments2graph(fragments, quest_name)
# Out:
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (
# .
# \(
# (

# %%
quest_graph.number_of_edges()
# Out:
# 156

# %%
QUESTBOOKS_GRAPH_DIRECTORY = 'D:\Диплом_текстовые_квесты\Data\questbook_graphs'

# %%
for file in tqdm(os.listdir(FRAGMENTS_JSON_DIRECTORY)):
    quest_name = os.path.splitext(file)[0]
    fragments_path = os.path.join(FRAGMENTS_JSON_DIRECTORY, file)
    fragments = json.load(open(fragments_path, encoding='utf-8'))
    
    if isinstance(fragments, dict):
        quest_graph = book_fragments2graph(fragments, quest_name)
        quest_graph_json = json_graph.node_link_data(quest_graph)
        with open(os.path.join(QUESTBOOKS_GRAPH_DIRECTORY, file), 'w', encoding='utf-8') as f:
            json.dump(quest_graph_json, f)
# Out:
#   0%|                                                                                          | 0/173 [00:00<?, ?it/s]
#
#
#   1%|▍                                                                                 | 1/173 [00:00<00:18,  9.53it/s]
#
#
#   1%|▉                                                                                 | 2/173 [00:00<00:20,  8.45it/s]
#
#
#   2%|█▍                                                                                | 3/173 [00:00<00:21,  8.05it/s]
#
#
#   3%|██▎                                                                               | 5/173 [00:00<00:18,  8.96it/s]
#
#
#   3%|██▊                                                                               | 6/173 [00:01<00:38,  4.32it/s]
#
#
#   4%|███▎                                                                              | 7/173 [00:02<01:28,  1.88it/s]
#
#
#   5%|███▊                                                                              | 8/173 [00:02<01:15,  2.20it/s]
#
#
#   5%|████▎                                                                             | 9/173 [00:03<01:28,  1.86it/s]
#
#
#   7%|█████▌                                                                           | 12/173 [00:03<01:05,  2.44it/s]
#
#
#   8%|██████                                                                           | 13/173 [00:03<00:55,  2.89it/s]
#
#
#   9%|███████                                                                          | 15/173 [00:04<00:43,  3.60it/s]
#
#
#  10%|███████▉                                                                         | 17/173 [00:04<00:34,  4.46it/s]
#
#
#  11%|████████▉                                                                        | 19/173 [00:04<00:26,  5.76it/s]
#
#
#  12%|█████████▊                                                                       | 21/173 [00:04<00:24,  6.31it/s]
#
#
#  13%|██████████▎                                                                      | 22/173 [00:04<00:24,  6.13it/s]
#
#
#  14%|███████████▏                                                                     | 24/173 [00:05<00:22,  6.51it/s]
#
#
#  15%|████████████▏                                                                    | 26/173 [00:05<00:18,  8.13it/s]
#
#
#  16%|█████████████                                                                    | 28/173 [00:05<00:16,  8.82it/s]
#
#
#  17%|██████████████                                                                   | 30/173 [00:05<00:13, 10.52it/s]
#
#
#  18%|██████████████▉                                                                  | 32/173 [00:05<00:15,  9.00it/s]
#
#
#  20%|███████████████▉                                                                 | 34/173 [00:06<00:17,  7.83it/s]
#
#
#  20%|████████████████▍                                                                | 35/173 [00:06<00:16,  8.31it/s]
#
#
#  21%|█████████████████▎                                                               | 37/173 [00:06<00:19,  6.84it/s]
#
#
#  23%|██████████████████▎                                                              | 39/173 [00:06<00:15,  8.41it/s]
#
#
#  24%|███████████████████▏                                                             | 41/173 [00:06<00:13,  9.90it/s]
#
#
#  25%|████████████████████▌                                                            | 44/173 [00:06<00:10, 11.91it/s]
#
#
#  27%|█████████████████████▌                                                           | 46/173 [00:07<00:13,  9.39it/s]
#
#
#  28%|██████████████████████▍                                                          | 48/173 [00:08<00:26,  4.64it/s]
#
#
#  28%|██████████████████████▉                                                          | 49/173 [00:08<00:26,  4.71it/s]
#
#
#  29%|███████████████████████▍                                                         | 50/173 [00:08<00:32,  3.75it/s]
#
#
#  29%|███████████████████████▉                                                         | 51/173 [00:09<00:32,  3.79it/s]
#
#
#  30%|████████████████████████▎                                                        | 52/173 [00:09<00:26,  4.64it/s]
#
#
#  31%|█████████████████████████▎                                                       | 54/173 [00:09<00:21,  5.43it/s]
#
#
#  32%|██████████████████████████▏                                                      | 56/173 [00:09<00:17,  6.80it/s]
#
#
#  34%|███████████████████████████▏                                                     | 58/173 [00:09<00:19,  5.80it/s]
#
#
#  34%|███████████████████████████▌                                                     | 59/173 [00:10<00:27,  4.18it/s]
#
#
#  35%|████████████████████████████                                                     | 60/173 [00:10<00:24,  4.56it/s]
#
#
#  36%|█████████████████████████████                                                    | 62/173 [00:10<00:21,  5.27it/s]
#
#
#  37%|█████████████████████████████▉                                                   | 64/173 [00:10<00:17,  6.40it/s]
#
#
#  38%|██████████████████████████████▍                                                  | 65/173 [00:11<00:16,  6.62it/s]
#
#
#  38%|██████████████████████████████▉                                                  | 66/173 [00:11<00:15,  6.73it/s]
#
#
#  40%|████████████████████████████████▎                                                | 69/173 [00:11<00:12,  8.54it/s]
#
#
#  41%|█████████████████████████████████▏                                               | 71/173 [00:12<00:25,  3.98it/s]
#
#
#  42%|██████████████████████████████████▏                                              | 73/173 [00:12<00:22,  4.47it/s]
#
#
#  43%|██████████████████████████████████▋                                              | 74/173 [00:13<00:22,  4.47it/s]
#
#
#  44%|███████████████████████████████████▌                                             | 76/173 [00:13<00:20,  4.81it/s]
#
#
#  46%|████████████████████████████████████▉                                            | 79/173 [00:13<00:16,  5.66it/s]
#
#
#  47%|█████████████████████████████████████▉                                           | 81/173 [00:13<00:13,  6.67it/s]
#
#
#  47%|██████████████████████████████████████▍                                          | 82/173 [00:14<00:14,  6.21it/s]
#
#
#  48%|██████████████████████████████████████▊                                          | 83/173 [00:14<00:15,  5.77it/s]
#
#
#  49%|███████████████████████████████████████▎                                         | 84/173 [00:14<00:17,  5.05it/s]
#
#
#  50%|████████████████████████████████████████▎                                        | 86/173 [00:14<00:13,  6.29it/s]
#
#
#  50%|████████████████████████████████████████▋                                        | 87/173 [00:14<00:12,  6.75it/s]
#
#
#  51%|█████████████████████████████████████████▏                                       | 88/173 [00:14<00:11,  7.41it/s]
#
#
#  51%|█████████████████████████████████████████▋                                       | 89/173 [00:15<00:15,  5.57it/s]
#
#
#  53%|██████████████████████████████████████████▌                                      | 91/173 [00:15<00:11,  6.98it/s]
#
#
#  54%|███████████████████████████████████████████▌                                     | 93/173 [00:15<00:10,  7.89it/s]
#
#
#  55%|████████████████████████████████████████████▍                                    | 95/173 [00:15<00:09,  8.05it/s]
#
#
#  55%|████████████████████████████████████████████▉                                    | 96/173 [00:15<00:13,  5.74it/s]
#
#
#  56%|█████████████████████████████████████████████▍                                   | 97/173 [00:16<00:19,  4.00it/s]
#
#
#  57%|█████████████████████████████████████████████▉                                   | 98/173 [00:16<00:20,  3.60it/s]
#
#
#  58%|██████████████████████████████████████████████▋                                 | 101/173 [00:17<00:18,  3.84it/s]
#
#
#  59%|███████████████████████████████████████████████▏                                | 102/173 [00:17<00:16,  4.27it/s]
#
#
#  60%|███████████████████████████████████████████████▋                                | 103/173 [00:17<00:13,  5.13it/s]
#
#
#  60%|████████████████████████████████████████████████                                | 104/173 [00:17<00:11,  5.87it/s]
#
#
#  61%|████████████████████████████████████████████████▌                               | 105/173 [00:18<00:14,  4.84it/s]
#
#
#  62%|█████████████████████████████████████████████████▍                              | 107/173 [00:18<00:11,  5.96it/s]
#
#
#  62%|█████████████████████████████████████████████████▉                              | 108/173 [00:18<00:10,  6.37it/s]
#
#
#  64%|███████████████████████████████████████████████████▎                            | 111/173 [00:18<00:08,  7.58it/s]
#
#
#  65%|███████████████████████████████████████████████████▊                            | 112/173 [00:18<00:09,  6.62it/s]
#
#
#  65%|████████████████████████████████████████████████████▎                           | 113/173 [00:19<00:11,  5.33it/s]
#
#
#  66%|████████████████████████████████████████████████████▋                           | 114/173 [00:19<00:09,  5.95it/s]
#
#
#  66%|█████████████████████████████████████████████████████▏                          | 115/173 [00:19<00:09,  6.15it/s]
#
#
#  67%|█████████████████████████████████████████████████████▋                          | 116/173 [00:19<00:11,  5.06it/s]
#
#
#  69%|███████████████████████████████████████████████████████                         | 119/173 [00:19<00:08,  6.36it/s]
#
#
#  69%|███████████████████████████████████████████████████████▍                        | 120/173 [00:20<00:10,  5.28it/s]
#
#
#  71%|████████████████████████████████████████████████████████▍                       | 122/173 [00:20<00:08,  6.35it/s]
#
#
#  71%|████████████████████████████████████████████████████████▉                       | 123/173 [00:20<00:07,  6.88it/s]
#
#
#  72%|█████████████████████████████████████████████████████████▊                      | 125/173 [00:21<00:09,  5.03it/s]
#
#
#  73%|██████████████████████████████████████████████████████████▋                     | 127/173 [00:21<00:07,  6.08it/s]
#
#
#  75%|███████████████████████████████████████████████████████████▋                    | 129/173 [00:21<00:07,  6.26it/s]
#
#
#  75%|████████████████████████████████████████████████████████████                    | 130/173 [00:21<00:06,  6.32it/s]
#
#
#  76%|████████████████████████████████████████████████████████████▌                   | 131/173 [00:21<00:06,  6.91it/s]
#
#
#  77%|█████████████████████████████████████████████████████████████▌                  | 133/173 [00:21<00:05,  7.80it/s]
#
#
#  77%|█████████████████████████████████████████████████████████████▉                  | 134/173 [00:22<00:05,  6.93it/s]
#
#
#  78%|██████████████████████████████████████████████████████████████▍                 | 135/173 [00:22<00:05,  6.98it/s]
#
#
#  79%|██████████████████████████████████████████████████████████████▉                 | 136/173 [00:22<00:04,  7.44it/s]
#
#
#  79%|███████████████████████████████████████████████████████████████▎                | 137/173 [00:22<00:07,  4.75it/s]
#
#
#  80%|████████████████████████████████████████████████████████████████▎               | 139/173 [00:22<00:06,  5.57it/s]
#
#
#  82%|█████████████████████████████████████████████████████████████████▏              | 141/173 [00:23<00:05,  5.63it/s]
#
#
#  82%|█████████████████████████████████████████████████████████████████▋              | 142/173 [00:23<00:08,  3.74it/s]
#
#
#  83%|██████████████████████████████████████████████████████████████████▌             | 144/173 [00:24<00:07,  4.10it/s]
#
#
#  84%|███████████████████████████████████████████████████████████████████             | 145/173 [00:24<00:07,  3.67it/s]
#
#
#  85%|███████████████████████████████████████████████████████████████████▉            | 147/173 [00:24<00:06,  4.18it/s]
#
#
#  86%|████████████████████████████████████████████████████████████████████▍           | 148/173 [00:25<00:06,  3.68it/s]
#
#
#  87%|█████████████████████████████████████████████████████████████████████▎          | 150/173 [00:25<00:04,  4.68it/s]
#
#
#  87%|█████████████████████████████████████████████████████████████████████▊          | 151/173 [00:25<00:04,  5.48it/s]
#
#
#  88%|██████████████████████████████████████████████████████████████████████▊         | 153/173 [00:25<00:03,  6.32it/s]
#
#
#  89%|███████████████████████████████████████████████████████████████████████▏        | 154/173 [00:25<00:03,  5.87it/s]
#
#
#  90%|████████████████████████████████████████████████████████████████████████▏       | 156/173 [00:26<00:03,  5.49it/s]
#
#
#  92%|█████████████████████████████████████████████████████████████████████████▌      | 159/173 [00:26<00:02,  6.43it/s]
#
#
#  92%|█████████████████████████████████████████████████████████████████████████▉      | 160/173 [00:26<00:02,  4.83it/s]
#
#
#  93%|██████████████████████████████████████████████████████████████████████████▍     | 161/173 [00:26<00:02,  5.62it/s]
#
#
#  94%|██████████████████████████████████████████████████████████████████████████▉     | 162/173 [00:27<00:03,  2.96it/s]
#
#
#  95%|███████████████████████████████████████████████████████████████████████████▊    | 164/173 [00:27<00:02,  3.56it/s]
#
#
#  95%|████████████████████████████████████████████████████████████████████████████▎   | 165/173 [00:28<00:02,  3.59it/s]
#
#
#  96%|████████████████████████████████████████████████████████████████████████████▊   | 166/173 [00:28<00:01,  3.98it/s]
#
#
#  97%|█████████████████████████████████████████████████████████████████████████████▋  | 168/173 [00:28<00:00,  5.21it/s]
#
#
#  98%|██████████████████████████████████████████████████████████████████████████████▏ | 169/173 [00:28<00:00,  5.43it/s]
#
#
#  98%|██████████████████████████████████████████████████████████████████████████████▌ | 170/173 [00:28<00:00,  5.06it/s]
#
#
# 100%|████████████████████████████████████████████████████████████████████████████████| 173/173 [00:29<00:00,  5.95it/s]

# %%
graph_statistics = pd.DataFrame(columns=['file', 'num_nodes', 'num_edges', 'num_real_starts'])
for file in os.listdir(QUESTBOOKS_GRAPH_DIRECTORY):
    file_path = os.path.join(QUESTBOOKS_GRAPH_DIRECTORY, file)
    graph_data = json.load(open(file_path, encoding='utf-8'))
    G = json_graph.node_link_graph(graph_data)
    
    num_nodes = G.number_of_nodes()
    num_edges = G.number_of_edges()
    num_real_starts = len([node for node in G.nodes() if G.in_degree(node) == 0 and G.out_degree(node) > 0])
    
    graph_statistics.loc[len(graph_statistics)] = [file, num_nodes, num_edges, num_real_starts]

# %%
problem_files = list(graph_statistics[graph_statistics['num_edges'] == 0]['file'])
problem_files
# Out:
# []

# %%
for file in problem_files:
    file_path = os.path.join(QUESTBOOKS_GRAPH_DIRECTORY, file)
    os.remove(file_path)

# %%
graph_statistics[graph_statistics['num_real_starts']==1]
# Out:
#                                                file num_nodes num_edges  \
# 3                                       dafin1.json       130       129
# 4                                        dogs2.json       115       156
# 10                                     fairysh.json        59        76
# 20                                     GD-demo.json        64       154
# 27                              SW4 (A5, v1.0).json        31        30
# 30                                         zhc.json       141       215
# 33                       Алькатрас - П.Горохов.json       113       157
# 38         Большое приключение малыша Лешеньки.json        48        62
# 43                                В тени трона.json        84       135
# 54                          Город бешеных псов.json       122       194
# 61              Емельянова__Искушение_студента.json       319       318
# 62                                  Жаброносец.json       227       323
# 65                   Замок потерянных душ - ч1.json       104       186
# 66                   Замок потерянных душ - ч2.json        93       152
# 68                   Замок потерянных душ - ч4.json        89       141
# 72                              КВЕСТ Реликвия.json        68       135
# 95                                 Микрорыцарь.json        25        35
# 101                    Непредвиденный пассажир.json       212       357
# 109              Оружие возмездия - книга-игра.json       169       249
# 123                       Подземная дорога 1.1.json       103       147
# 150                      Суровый Школьный День.json        28        36
# 152                          Темный узурпатор1.json       104       175
# 153                              Точка отсчёта.json        95       262
# 154                          Три дороги (v1.1).json       354       707
# 167  Эдвард Паккард - Тайна заброшенного замка.json        95       104
#
#     num_real_starts
# 3                 1
# 4                 1
# 10                1
# 20                1
# 27                1
# 30                1
# 33                1
# 38                1
# 43                1
# 54                1
# 61                1
# 62                1
# 65                1
# 66                1
# 68                1
# 72                1
# 95                1
# 101               1
# 109               1
# 123               1
# 150               1
# 152               1
# 153               1
# 154               1
# 167               1

# %%
graph_statistics[graph_statistics['num_edges']!=0]
# Out:
#                                                file num_nodes num_edges  \
# 0                                 BB1rusKalgor.json        73        84
# 1                           Black_Panther_v1.2.json       219       313
# 2                            Cherniy continent.json       354       612
# 3                                       dafin1.json       130       129
# 4                                        dogs2.json       115       156
# ..                                              ...       ...       ...
# 164                           Человекосжималки.json       135       137
# 165             Шерлок Холмс 3 (без фона) v1.1.json       530       881
# 166                       Школа для смельчаков.json       101       157
# 167  Эдвард Паккард - Тайна заброшенного замка.json        95       104
# 168                                Элгар Флетч.json        83        99
#
#     num_real_starts
# 0                11
# 1                 4
# 2                 5
# 3                 1
# 4                 1
# ..              ...
# 164               3
# 165               5
# 166              13
# 167               1
# 168               8
#
# [169 rows x 4 columns]
